# %%
import pandas as pd
import matplotlib.pyplot as plt  
import numpy as np
import csv

np.set_printoptions(precision=10)
import sys
import random
from random import seed
from random import randint
from sklearn.metrics import accuracy_score
from bs4 import BeautifulSoup

from random import randrange

from scipy.special import expit
from scipy.special import softmax

pd.option_context('display.max_rows', None, 'display.max_columns', None)  # more options can be specified also
np.set_printoptions(threshold=sys.maxsize)
seed(1)

np.set_printoptions(precision=10, )
pd.options.display.float_format = '{:.2f}'.format
np.set_printoptions(suppress=True)

# %precision 10
# !cp -r /content/drive/MyDrive/10601_DataSets /content

'''
We will be using a subset of an Optical Character Recognition (OCR) dataset. This data includes
images of all 26 handwritten letters; our subset will include only the letters “a,” “e,” “g,” “i,” “l,” “n,” “o,”
“r,” “t,” and “u.” 
The handout contains three datasets drawn from this data: 
a small dataset with 60 samples per class (50 for training and 10 for test), 
a medium dataset with 600 samples per class (500 for training and 100 for test), and 
a large dataset with 1000 samples per class (900 for training and 100 for test).

File Format Each dataset (small, medium, and large) consists of two csv files—train and test. 

Each row contains 129 columns separated by commas. 

The first column contains the label and columns 2 to 129 represent the pixel values of 
a 16 x 8 image in a row major format. 

Label 0 corresponds to “a,” 1 to “e,” 2 to “g,” 3 to “i,” 4 to “l,” 5 to “n,” 6 to “o,” 7 to “r,” 8 to “t,” and 9 to “u.” 

Because the original images are black-and-white (not grayscale), the pixel values are either 0 or 1. 
However, you should write your code to accept arbitrary pixel values in the range [0,1]. 

Observe that no feature engineering has been done here; instead the neural network you build
will learn features appropriate for the task of character recognition.
'''
# Out:
# '\nWe will be using a subset of an Optical Character Recognition (OCR) dataset. This data includes\nimages of all 26 handwritten letters; our subset will include only the letters “a,” “e,” “g,” “i,” “l,” “n,” “o,”\n“r,” “t,” and “u.” \nThe handout contains three datasets drawn from this data: \na small dataset with 60 samples per class (50 for training and 10 for test), \na medium dataset with 600 samples per class (500 for training and 100 for test), and \na large dataset with 1000 samples per class (900 for training and 100 for test).\n\nFile Format Each dataset (small, medium, and large) consists of two csv files—train and test. \n\nEach row contains 129 columns separated by commas. \n\nThe first column contains the label and columns 2 to 129 represent the pixel values of \na 16 x 8 image in a row major format. \n\nLabel 0 corresponds to “a,” 1 to “e,” 2 to “g,” 3 to “i,” 4 to “l,” 5 to “n,” 6 to “o,” 7 to “r,” 8 to “t,” and 9 to “u.” \n\nBecause the original images are black-and-white (not grayscale), the pixel values are either 0 or 1. \nHowever, you should write your code to accept arbitrary pixel values in the range [0,1]. \n\nObserve that no feature engineering has been done here; instead the neural network you build\nwill learn features appropriate for the task of character recognition.\n'

# %%
# !tar -xf /content/10601_DataSets/HW5/handout.tar

# %%
large_test = pd.read_csv('/content/handout/largeTest.csv', sep= ',', header=None)
large_train = pd.read_csv('/content/handout/largeTrain.csv', sep= ',', header=None)

print("Training data shape: ", large_train.shape)
print("test data shape: ", large_test.shape)

large_test.rename(columns={0:'Label'}, inplace=True)
large_train.rename(columns={0:'Label'}, inplace=True)
# Out:
# Training data shape:  (9000, 129)
# test data shape:  (1000, 129)

# %%
def weight_init(choice, height, width):
  if choice == "RANDOM":
    return np.random.uniform(low=-0.1, high=0.1, size=(height, width))
  else:
    return np.zeros([height, width])

# %%
def NNForward(train_example, train_label, alpha_train, beta_train):
  a = LinearForward(alpha_train, train_example)
  z = SigmoidForward(a)
  
  z_biased = np.vstack((1, z))
  b = LinearForward(beta_train, z_biased)

  y_hat = SoftmaxForward(b)
  J = CrossEntropyForward(train_label, y_hat)

  ForwardProp = {}

  ForwardProp['train_example'] = train_example
  ForwardProp['train_label'] = train_label

  ForwardProp['LinearForward_1'] = a
  ForwardProp['SigmoidForward'] = z

  ForwardProp['SigmoidForward_biased'] = z_biased
  ForwardProp['LinearForward_2'] = b

  ForwardProp['SoftmaxForward'] = y_hat
  ForwardProp['CrossEntropyForward'] = J
  return ForwardProp

# %%
def NNBackward(train_example, train_label, alpha_train, beta_train, properties):

  x = properties['train_example']
  y_true = properties['train_label']
  
  a = properties['LinearForward_1']
  z = properties['SigmoidForward']

  z_biased = properties['SigmoidForward_biased']
  b = properties['LinearForward_2']

  y_hat = properties['SoftmaxForward']
  J = properties['CrossEntropyForward']

  gj = 1

  g_yhat = CrossEntropyBackward(y_true, y_hat, J, gj)
  
  gb = SoftmaxBackward(b, y_hat, g_yhat)
  
  g_beta, gz = LinearBackward(z_biased, beta_train, gb.T)
  ga = SigmoidBackward(z, gz)

  g_alpha, _ = LinearBackward(x, a, ga)

  return g_alpha, g_beta

# %%
def calc_cross_entropy(y_pred_mat, y_true_mat):

  log_predictions = np.log(y_pred_mat)
  multi = np.multiply(log_predictions, y_true_mat)
  summation = multi.sum(axis = 1)
  summation = -1 * summation.sum(axis = 0) / y_true_mat.shape[0]
  print("Cross entropy: ", summation)
  return summation

# %%
def SigmoidForward(a):
  # shape: D x 1 or K x 1
  b = expit(a)
  return b

def SigmoidBackward(z, gz):
  ga = np.multiply(np.multiply(gz, z), (1 - z))
  return ga

def SoftmaxForward(a):
  # k x 1
  b = softmax(a)
  return b

def SoftmaxBackward(a, b, gb):

  diag_b = np.multiply(np.identity(a.shape[0]), b)

  ga = np.dot(gb.T, (diag_b - np.dot(b, b.T)))
  
  return ga

# %%
def LinearForward(w, x):
  # b     =   (weights)     *    X(input)
  # D x 1 = D x (M + 1) * (M + 1) x 1
  # k x 1 = k x (D + 1) * (D + 1) x 1
  assert w.shape[1] == x.shape[0], "LinearForward error in shape"
  b = np.dot(w, x)
  return b

def LinearBackward(a, w, gb):
  assert gb.shape[1] == a.T.shape[0], "Error in LinearBackward"
  # gw = D x (M + 1) = (D x 1) * (1 x (M + 1))
  # gw = k x (D + 1) = (k x 1) * (1 x (D +1))
  gw = np.dot(gb, a.T)
  ga = np.dot(w[:,1:].T, gb)

  return gw, ga

# %%
def CrossEntropyForward(a, a_hat):
  # out = 1 x 1 = (1 x k) * (k x 1)
  assert a.shape[0] == a_hat.shape[0], "Error in CrossEntropyForward"
  b = -1 * np.dot(a.T, a_hat)
  return b

def CrossEntropyBackward(a, a_hat, b, gb):
  # Return K x 1 vector
  ga_hat = -gb * (a / a_hat)

  assert a.shape[0] == a_hat.shape[0], "Error in output shape in CrossEntropyForward"
  assert ga_hat.shape[0] != 1
  return ga_hat

# %%
def SGD_Procedure(df_train, df_test, epochs, learning_rate, 
                  num_classes, num_features, num_hidden,
                  weight_init_method):
  
  alpha = weight_init(weight_init_method, num_hidden, num_features)
  beta = weight_init(weight_init_method, num_classes, num_hidden)
  
  alpha = np.hstack((np.zeros((num_hidden, 1)), alpha))
  beta = np.hstack((np.zeros((num_classes, 1)), beta))
  
  cross_test_list = []
  cross_train_list = []

  for epoch in range(0, epochs):
    
    arr_true = 0
    arr_pred = 0
    arr_test = 0
    arr_true_test = 0
    flag = 0

    print("EPOCH NUMBER: ", epoch)
    for index, row in df_train.iterrows():
      
      # Training example and label
      label = row['Label']
      tr_label = np.zeros([num_classes, 1])
      tr_label[label] = 1

      exmp = np.array(row.to_numpy().reshape(129, 1))
      exmp[0] = 1
      
      # Forward probagation for train example
      forward_result = NNForward(exmp, tr_label, alpha, beta)
      
      # Backward probagation for train example
      grad_alpha, grad_beta = NNBackward(exmp, tr_label, alpha, beta, forward_result)
      
      if flag == 0:
        arr_true = tr_label.reshape(1, 10)
        arr_pred = forward_result['SoftmaxForward'].reshape(1, 10)
      else:
        arr_true = np.vstack((tr_label.reshape(1, 10), arr_true))
        arr_pred = np.vstack((forward_result['SoftmaxForward'].reshape(1, 10), arr_pred))

      if index < df_test.shape[0]:
        # Test example and label
        ts_label = large_test.iloc[index]['Label']
        ts_label_arr = np.zeros([num_classes, 1])
        ts_label_arr[ts_label] = 1

        exmp_test = np.array(large_test.iloc[index].to_numpy().reshape(129, 1))
        exmp_test[0] = 1

        # Forward probagation for test example
        forward_result = NNForward(exmp_test, ts_label_arr, alpha, beta)

        if flag == 0:
          arr_true_test = ts_label_arr.reshape(1, 10)
          arr_test = forward_result['SoftmaxForward'].reshape(1, 10)
        else:
          arr_true_test = np.vstack((ts_label_arr.reshape(1, 10), arr_true_test))
          arr_test = np.vstack((forward_result['SoftmaxForward'].reshape(1, 10), arr_test))

      alpha = alpha - learning_rate * grad_alpha
      beta = beta -  learning_rate * grad_beta

      flag += 1

    print("Train cross entropy: ")
    cross_train_list.append(calc_cross_entropy(arr_pred, arr_true))
    print("Test cross entropy: ")
    cross_test_list.append(calc_cross_entropy(arr_test, arr_true_test))

  return alpha, beta, cross_test_list, cross_train_list

a, b, test_cross, train_cross = SGD_Procedure(df_train=large_train, df_test=large_test, epochs=100,
                                              learning_rate=0.01, num_classes=10, num_features=128, 
                                              num_hidden=50, weight_init_method="RANDOM")
# Out:
# EPOCH NUMBER:  0
# Train cross entropy:
# Cross entropy:  1.5802529790287265
# Test cross entropy:
# Cross entropy:  2.3160339438600483
# EPOCH NUMBER:  1
# Train cross entropy:
# Cross entropy:  0.8087284879210123
# Test cross entropy:
# Cross entropy:  1.0004392565519131
# EPOCH NUMBER:  2
# Train cross entropy:
# Cross entropy:  0.6557673900270873
# Test cross entropy:
# Cross entropy:  0.7626594707535299
# EPOCH NUMBER:  3
# Train cross entropy:
# Cross entropy:  0.5865542270113585
# Test cross entropy:
# Cross entropy:  0.6824494359119924
# EPOCH NUMBER:  4
# Train cross entropy:
# Cross entropy:  0.5411064183971053
# Test cross entropy:
# Cross entropy:  0.6378484195071699
# EPOCH NUMBER:  5
# Train cross entropy:
# Cross entropy:  0.5066606746596455
# Test cross entropy:
# Cross entropy:  0.607451968595479
# EPOCH NUMBER:  6
# Train cross entropy:
# Cross entropy:  0.47833650357736224
# Test cross entropy:
# Cross entropy:  0.5841154337094183
# EPOCH NUMBER:  7
# Train cross entropy:
# Cross entropy:  0.4538654493237793
# Test cross entropy:
# Cross entropy:  0.5648920053230773
# EPOCH NUMBER:  8
# Train cross entropy:
# Cross entropy:  0.4321106620748743
# Test cross entropy:
# Cross entropy:  0.5484013027227047
# EPOCH NUMBER:  9
# Train cross entropy:
# Cross entropy:  0.41246459946018466
# Test cross entropy:
# Cross entropy:  0.5339546403066436
# EPOCH NUMBER:  10
# Train cross entropy:
# Cross entropy:  0.39456348517453116
# Test cross entropy:
# Cross entropy:  0.5211670358914711
# EPOCH NUMBER:  11
# Train cross entropy:
# Cross entropy:  0.3781503336056292
# Test cross entropy:
# Cross entropy:  0.5097630422137044
# EPOCH NUMBER:  12
# Train cross entropy:
# Cross entropy:  0.3630202187204297
# Test cross entropy:
# Cross entropy:  0.4995080377200209
# EPOCH NUMBER:  13
# Train cross entropy:
# Cross entropy:  0.3490028065100679
# Test cross entropy:
# Cross entropy:  0.49020338995826324
# EPOCH NUMBER:  14
# Train cross entropy:
# Cross entropy:  0.3359553640666642
# Test cross entropy:
# Cross entropy:  0.4816896391669443
# EPOCH NUMBER:  15
# Train cross entropy:
# Cross entropy:  0.323758239163301
# Test cross entropy:
# Cross entropy:  0.473843729907623
# EPOCH NUMBER:  16
# Train cross entropy:
# Cross entropy:  0.3123113120302299
# Test cross entropy:
# Cross entropy:  0.46657403409355436
# EPOCH NUMBER:  17
# Train cross entropy:
# Cross entropy:  0.3015308038841756
# Test cross entropy:
# Cross entropy:  0.4598151480013
# EPOCH NUMBER:  18
# Train cross entropy:
# Cross entropy:  0.291346534703267
# Test cross entropy:
# Cross entropy:  0.4535224472009607
# EPOCH NUMBER:  19
# Train cross entropy:
# Cross entropy:  0.2816999624403831
# Test cross entropy:
# Cross entropy:  0.44766634497564595
# EPOCH NUMBER:  20
# Train cross entropy:
# Cross entropy:  0.27254284219409275
# Test cross entropy:
# Cross entropy:  0.44222671215842557
# EPOCH NUMBER:  21
# Train cross entropy:
# Cross entropy:  0.2638359405907084
# Test cross entropy:
# Cross entropy:  0.4371882521649342
# EPOCH NUMBER:  22
# Train cross entropy:
# Cross entropy:  0.2555474123319758
# Test cross entropy:
# Cross entropy:  0.43253764489192625
# EPOCH NUMBER:  23
# Train cross entropy:
# Cross entropy:  0.24765091216808174
# Test cross entropy:
# Cross entropy:  0.42826281672116406
# EPOCH NUMBER:  24
# Train cross entropy:
# Cross entropy:  0.24012375488340387
# Test cross entropy:
# Cross entropy:  0.4243535479440914
# EPOCH NUMBER:  25
# Train cross entropy:
# Cross entropy:  0.2329453290252139
# Test cross entropy:
# Cross entropy:  0.4208015331068884
# EPOCH NUMBER:  26
# Train cross entropy:
# Cross entropy:  0.2260959206171069
# Test cross entropy:
# Cross entropy:  0.4175986078423382
# EPOCH NUMBER:  27
# Train cross entropy:
# Cross entropy:  0.21955618900504614
# Test cross entropy:
# Cross entropy:  0.41473414494956556
# EPOCH NUMBER:  28
# Train cross entropy:
# Cross entropy:  0.21330733521429088
# Test cross entropy:
# Cross entropy:  0.41219378128385237
# EPOCH NUMBER:  29
# Train cross entropy:
# Cross entropy:  0.20733163807787877
# Test cross entropy:
# Cross entropy:  0.409960178976979
# EPOCH NUMBER:  30
# Train cross entropy:
# Cross entropy:  0.20161292014419338
# Test cross entropy:
# Cross entropy:  0.4080147163709985
# EPOCH NUMBER:  31
# Train cross entropy:
# Cross entropy:  0.19613666329686852
# Test cross entropy:
# Cross entropy:  0.40633887768652377
# EPOCH NUMBER:  32
# Train cross entropy:
# Cross entropy:  0.19088976473364835
# Test cross entropy:
# Cross entropy:  0.4049149629789208
# EPOCH NUMBER:  33
# Train cross entropy:
# Cross entropy:  0.18586012230984633
# Test cross entropy:
# Cross entropy:  0.4037262837292673
# EPOCH NUMBER:  34
# Train cross entropy:
# Cross entropy:  0.18103626079719615
# Test cross entropy:
# Cross entropy:  0.40275709891049644
# EPOCH NUMBER:  35
# Train cross entropy:
# Cross entropy:  0.17640711047999666
# Test cross entropy:
# Cross entropy:  0.40199249554497446
# EPOCH NUMBER:  36
# Train cross entropy:
# Cross entropy:  0.1719619409886686
# Test cross entropy:
# Cross entropy:  0.4014183344258452
# EPOCH NUMBER:  37
# Train cross entropy:
# Cross entropy:  0.16769039931575502
# Test cross entropy:
# Cross entropy:  0.4010212825844109
# EPOCH NUMBER:  38
# Train cross entropy:
# Cross entropy:  0.1635825971859963
# Test cross entropy:
# Cross entropy:  0.4007888832295099
# EPOCH NUMBER:  39
# Train cross entropy:
# Cross entropy:  0.1596292100512023
# Test cross entropy:
# Cross entropy:  0.4007095977090172
# EPOCH NUMBER:  40
# Train cross entropy:
# Cross entropy:  0.15582156699128083
# Test cross entropy:
# Cross entropy:  0.4007727780460518
# EPOCH NUMBER:  41
# Train cross entropy:
# Cross entropy:  0.15215172079646397
# Test cross entropy:
# Cross entropy:  0.4009685642589079
# EPOCH NUMBER:  42
# Train cross entropy:
# Cross entropy:  0.1486124904305445
# Test cross entropy:
# Cross entropy:  0.4012877294699682
# EPOCH NUMBER:  43
# Train cross entropy:
# Cross entropy:  0.1451974660168385
# Test cross entropy:
# Cross entropy:  0.4017215121294349
# EPOCH NUMBER:  44
# Train cross entropy:
# Cross entropy:  0.14190096440337632
# Test cross entropy:
# Cross entropy:  0.402261478348134
# EPOCH NUMBER:  45
# Train cross entropy:
# Cross entropy:  0.13871792900520807
# Test cross entropy:
# Cross entropy:  0.40289944742213224
# EPOCH NUMBER:  46
# Train cross entropy:
# Cross entropy:  0.13564378507768585
# Test cross entropy:
# Cross entropy:  0.4036274897728017
# EPOCH NUMBER:  47
# Train cross entropy:
# Cross entropy:  0.13267428308723037
# Test cross entropy:
# Cross entropy:  0.4044379768557029
# EPOCH NUMBER:  48
# Train cross entropy:
# Cross entropy:  0.12980537137546178
# Test cross entropy:
# Cross entropy:  0.4053236450036217
# EPOCH NUMBER:  49
# Train cross entropy:
# Cross entropy:  0.12703312484553259
# Test cross entropy:
# Cross entropy:  0.4062776415312734
# EPOCH NUMBER:  50
# Train cross entropy:
# Cross entropy:  0.12435372855282947
# Test cross entropy:
# Cross entropy:  0.40729354320920036
# EPOCH NUMBER:  51
# Train cross entropy:
# Cross entropy:  0.12176349407271861
# Test cross entropy:
# Cross entropy:  0.408365355571587
# EPOCH NUMBER:  52
# Train cross entropy:
# Cross entropy:  0.1192588831123138
# Test cross entropy:
# Cross entropy:  0.4094875070985633
# EPOCH NUMBER:  53
# Train cross entropy:
# Cross entropy:  0.11683652222019575
# Test cross entropy:
# Cross entropy:  0.41065484823211235
# EPOCH NUMBER:  54
# Train cross entropy:
# Cross entropy:  0.1144932042795818
# Test cross entropy:
# Cross entropy:  0.41186265744371875
# EPOCH NUMBER:  55
# Train cross entropy:
# Cross entropy:  0.11222588042627747
# Test cross entropy:
# Cross entropy:  0.4131066488415198
# EPOCH NUMBER:  56
# Train cross entropy:
# Cross entropy:  0.11003164897962485
# Test cross entropy:
# Cross entropy:  0.41438297056668033
# EPOCH NUMBER:  57
# Train cross entropy:
# Cross entropy:  0.10790774716463145
# Test cross entropy:
# Cross entropy:  0.41568818268720836
# EPOCH NUMBER:  58
# Train cross entropy:
# Cross entropy:  0.10585154849113032
# Test cross entropy:
# Cross entropy:  0.4170192081169996
# EPOCH NUMBER:  59
# Train cross entropy:
# Cross entropy:  0.10386056515823607
# Test cross entropy:
# Cross entropy:  0.41837325840162953
# EPOCH NUMBER:  60
# Train cross entropy:
# Cross entropy:  0.10193245207076142
# Test cross entropy:
# Cross entropy:  0.41974774460169456
# EPOCH NUMBER:  61
# Train cross entropy:
# Cross entropy:  0.10006500793390355
# Test cross entropy:
# Cross entropy:  0.4211401890023994
# EPOCH NUMBER:  62
# Train cross entropy:
# Cross entropy:  0.09825616979975181
# Test cross entropy:
# Cross entropy:  0.4225481545736427
# EPOCH NUMBER:  63
# Train cross entropy:
# Cross entropy:  0.09650399994881455
# Test cross entropy:
# Cross entropy:  0.42396920584105635
# EPOCH NUMBER:  64
# Train cross entropy:
# Cross entropy:  0.09480666689508217
# Test cross entropy:
# Cross entropy:  0.425400907691289
# EPOCH NUMBER:  65
# Train cross entropy:
# Cross entropy:  0.09316242413744759
# Test cross entropy:
# Cross entropy:  0.42684085921623577
# EPOCH NUMBER:  66
# Train cross entropy:
# Cross entropy:  0.091569590233834
# Test cross entropy:
# Cross entropy:  0.4282867509178062
# EPOCH NUMBER:  67
# Train cross entropy:
# Cross entropy:  0.09002653226130582
# Test cross entropy:
# Cross entropy:  0.4297364287206133
# EPOCH NUMBER:  68
# Train cross entropy:
# Cross entropy:  0.08853165298057773
# Test cross entropy:
# Cross entropy:  0.43118794892681384
# EPOCH NUMBER:  69
# Train cross entropy:
# Cross entropy:  0.08708338108803182
# Test cross entropy:
# Cross entropy:  0.4326396134583746
# EPOCH NUMBER:  70
# Train cross entropy:
# Cross entropy:  0.08568016399825061
# Test cross entropy:
# Cross entropy:  0.43408998167333257
# EPOCH NUMBER:  71
# Train cross entropy:
# Cross entropy:  0.08432046313602334
# Test cross entropy:
# Cross entropy:  0.43553786103744824
# EPOCH NUMBER:  72
# Train cross entropy:
# Cross entropy:  0.08300275209993616
# Test cross entropy:
# Cross entropy:  0.4369822825830894
# EPOCH NUMBER:  73
# Train cross entropy:
# Cross entropy:  0.0817255180004094
# Test cross entropy:
# Cross entropy:  0.4384224682723461
# EPOCH NUMBER:  74
# Train cross entropy:
# Cross entropy:  0.0804872658793833
# Test cross entropy:
# Cross entropy:  0.43985779670199027
# EPOCH NUMBER:  75
# Train cross entropy:
# Cross entropy:  0.07928652567484065
# Test cross entropy:
# Cross entropy:  0.4412877718595865
# EPOCH NUMBER:  76
# Train cross entropy:
# Cross entropy:  0.07812186092668684
# Test cross entropy:
# Cross entropy:  0.44271199759548535
# EPOCH NUMBER:  77
# Train cross entropy:
# Cross entropy:  0.07699187837607908
# Test cross entropy:
# Cross entropy:  0.44413015861880495
# EPOCH NUMBER:  78
# Train cross entropy:
# Cross entropy:  0.07589523768136452
# Test cross entropy:
# Cross entropy:  0.4455420074018625
# EPOCH NUMBER:  79
# Train cross entropy:
# Cross entropy:  0.07483066051269281
# Test cross entropy:
# Cross entropy:  0.44694735543760317
# EPOCH NUMBER:  80
# Train cross entropy:
# Cross entropy:  0.07379693821737948
# Test cross entropy:
# Cross entropy:  0.4483460668134994
# EPOCH NUMBER:  81
# Train cross entropy:
# Cross entropy:  0.07279293712147722
# Test cross entropy:
# Cross entropy:  0.4497380520422472
# EPOCH NUMBER:  82
# Train cross entropy:
# Cross entropy:  0.07181760050795244
# Test cross entropy:
# Cross entropy:  0.45112326056232327
# EPOCH NUMBER:  83
# Train cross entropy:
# Cross entropy:  0.07086994655074175
# Test cross entropy:
# Cross entropy:  0.45250167127352575
# EPOCH NUMBER:  84
# Train cross entropy:
# Cross entropy:  0.06994906202888809
# Test cross entropy:
# Cross entropy:  0.45387328169263136
# EPOCH NUMBER:  85
# Train cross entropy:
# Cross entropy:  0.06905409236943799
# Test cross entropy:
# Cross entropy:  0.4552380973616366
# EPOCH NUMBER:  86
# Train cross entropy:
# Cross entropy:  0.06818422925384283
# Test cross entropy:
# Cross entropy:  0.4565961235376169
# EPOCH NUMBER:  87
# Train cross entropy:
# Cross entropy:  0.06733869748358304
# Test cross entropy:
# Cross entropy:  0.4579473607387552
# EPOCH NUMBER:  88
# Train cross entropy:
# Cross entropy:  0.06651674293042965
# Test cross entropy:
# Cross entropy:  0.45929180463852737
# EPOCH NUMBER:  89
# Train cross entropy:
# Cross entropy:  0.0657176231489411
# Test cross entropy:
# Cross entropy:  0.4606294495680173
# EPOCH NUMBER:  90
# Train cross entropy:
# Cross entropy:  0.06494060162705752
# Test cross entropy:
# Cross entropy:  0.46196029396065386
# EPOCH NUMBER:  91
# Train cross entropy:
# Cross entropy:  0.06418494583910433
# Test cross entropy:
# Cross entropy:  0.463284345734967
# EPOCH NUMBER:  92
# Train cross entropy:
# Cross entropy:  0.06344992849657063
# Test cross entropy:
# Cross entropy:  0.46460162592632426
# EPOCH NUMBER:  93
# Train cross entropy:
# Cross entropy:  0.06273483090638882
# Test cross entropy:
# Cross entropy:  0.465912169684576
# EPOCH NUMBER:  94
# Train cross entropy:
# Cross entropy:  0.06203894724246562
# Test cross entropy:
# Cross entropy:  0.46721602470576135
# EPOCH NUMBER:  95
# Train cross entropy:
# Cross entropy:  0.061361588742631736
# Test cross entropy:
# Cross entropy:  0.46851324789771265
# EPOCH NUMBER:  96
# Train cross entropy:
# Cross entropy:  0.06070208719789779
# Test cross entropy:
# Cross entropy:  0.46980390138754546
# EPOCH NUMBER:  97
# Train cross entropy:
# Cross entropy:  0.060059797452352466
# Test cross entropy:
# Cross entropy:  0.47108804888048894
# EPOCH NUMBER:  98
# Train cross entropy:
# Cross entropy:  0.059434098894182816
# Test cross entropy:
# Cross entropy:  0.4723657530365185
# EPOCH NUMBER:  99
# Train cross entropy:
# Cross entropy:  0.05882439607103033
# Test cross entropy:
# Cross entropy:  0.4736370741298762

# %%
epochs = [i for i in range(1, 101)]
plt.title('Learning rate 0.01 for 100 epochs')
plt.xlabel("Epochs")
plt.ylabel("cross-entropy")
plt.plot(epochs, test_cross, color='green', label='Test cross-entropy')
plt.plot(epochs, train_cross, color='red', label='Training cross-entropy')
plt.legend()
plt.show()

# %%
a, b, test_cross, train_cross = SGD_Procedure(df_train=large_train, df_test=large_test, epochs=100,
                                              learning_rate=0.1, num_classes=10, num_features=128, 
                                              num_hidden=50, weight_init_method="RANDOM")
# Out:
# EPOCH NUMBER:  0
# Train cross entropy:
# Cross entropy:  0.7759669504021898
# Test cross entropy:
# Cross entropy:  1.7621960930125147
# EPOCH NUMBER:  1
# Train cross entropy:
# Cross entropy:  0.4365550754812219
# Test cross entropy:
# Cross entropy:  0.5508979632274178
# EPOCH NUMBER:  2
# Train cross entropy:
# Cross entropy:  0.33874942940310127
# Test cross entropy:
# Cross entropy:  0.4628186571258371
# EPOCH NUMBER:  3
# Train cross entropy:
# Cross entropy:  0.2787050176556504
# Test cross entropy:
# Cross entropy:  0.4267169427245586
# EPOCH NUMBER:  4
# Train cross entropy:
# Cross entropy:  0.23698245249361818
# Test cross entropy:
# Cross entropy:  0.4184903460547723
# EPOCH NUMBER:  5
# Train cross entropy:
# Cross entropy:  0.20390839383661494
# Test cross entropy:
# Cross entropy:  0.423084057863911
# EPOCH NUMBER:  6
# Train cross entropy:
# Cross entropy:  0.17759289893245497
# Test cross entropy:
# Cross entropy:  0.42947005282230066
# EPOCH NUMBER:  7
# Train cross entropy:
# Cross entropy:  0.15527516461222007
# Test cross entropy:
# Cross entropy:  0.4349866933997163
# EPOCH NUMBER:  8
# Train cross entropy:
# Cross entropy:  0.1365996312281664
# Test cross entropy:
# Cross entropy:  0.4472574576007581
# EPOCH NUMBER:  9
# Train cross entropy:
# Cross entropy:  0.12117408179000037
# Test cross entropy:
# Cross entropy:  0.46279095856936925
# EPOCH NUMBER:  10
# Train cross entropy:
# Cross entropy:  0.10830541156848723
# Test cross entropy:
# Cross entropy:  0.4771427324481542
# EPOCH NUMBER:  11
# Train cross entropy:
# Cross entropy:  0.0977203541573542
# Test cross entropy:
# Cross entropy:  0.48479739478028666
# EPOCH NUMBER:  12
# Train cross entropy:
# Cross entropy:  0.08896652668080895
# Test cross entropy:
# Cross entropy:  0.49039607755696607
# EPOCH NUMBER:  13
# Train cross entropy:
# Cross entropy:  0.08166539899860173
# Test cross entropy:
# Cross entropy:  0.4949720005703649
# EPOCH NUMBER:  14
# Train cross entropy:
# Cross entropy:  0.0756111365422043
# Test cross entropy:
# Cross entropy:  0.50209335124832
# EPOCH NUMBER:  15
# Train cross entropy:
# Cross entropy:  0.0705833770557277
# Test cross entropy:
# Cross entropy:  0.5085170544551099
# EPOCH NUMBER:  16
# Train cross entropy:
# Cross entropy:  0.06631421299014699
# Test cross entropy:
# Cross entropy:  0.5154336196369202
# EPOCH NUMBER:  17
# Train cross entropy:
# Cross entropy:  0.06266075672301798
# Test cross entropy:
# Cross entropy:  0.5228891358878116
# EPOCH NUMBER:  18
# Train cross entropy:
# Cross entropy:  0.05952585283456161
# Test cross entropy:
# Cross entropy:  0.5303536365462964
# EPOCH NUMBER:  19
# Train cross entropy:
# Cross entropy:  0.05679035212508913
# Test cross entropy:
# Cross entropy:  0.5383075280524033
# EPOCH NUMBER:  20
# Train cross entropy:
# Cross entropy:  0.05435459290005204
# Test cross entropy:
# Cross entropy:  0.5465531502161581
# EPOCH NUMBER:  21
# Train cross entropy:
# Cross entropy:  0.05223201948906881
# Test cross entropy:
# Cross entropy:  0.5538478087632449
# EPOCH NUMBER:  22
# Train cross entropy:
# Cross entropy:  0.05036121739717145
# Test cross entropy:
# Cross entropy:  0.5610645346604548
# EPOCH NUMBER:  23
# Train cross entropy:
# Cross entropy:  0.04868460737182981
# Test cross entropy:
# Cross entropy:  0.5684915456782885
# EPOCH NUMBER:  24
# Train cross entropy:
# Cross entropy:  0.04716940878731669
# Test cross entropy:
# Cross entropy:  0.5756721969108612
# EPOCH NUMBER:  25
# Train cross entropy:
# Cross entropy:  0.045795316620428544
# Test cross entropy:
# Cross entropy:  0.5826050007532719
# EPOCH NUMBER:  26
# Train cross entropy:
# Cross entropy:  0.044546255097207776
# Test cross entropy:
# Cross entropy:  0.5892296516357449
# EPOCH NUMBER:  27
# Train cross entropy:
# Cross entropy:  0.04341281605435298
# Test cross entropy:
# Cross entropy:  0.5954328962511353
# EPOCH NUMBER:  28
# Train cross entropy:
# Cross entropy:  0.04238295459644581
# Test cross entropy:
# Cross entropy:  0.6011953584239642
# EPOCH NUMBER:  29
# Train cross entropy:
# Cross entropy:  0.04144027805361891
# Test cross entropy:
# Cross entropy:  0.6066212095589846
# EPOCH NUMBER:  30
# Train cross entropy:
# Cross entropy:  0.04056725558456901
# Test cross entropy:
# Cross entropy:  0.6118338962113093
# EPOCH NUMBER:  31
# Train cross entropy:
# Cross entropy:  0.03974779975461647
# Test cross entropy:
# Cross entropy:  0.6169123217507979
# EPOCH NUMBER:  32
# Train cross entropy:
# Cross entropy:  0.03897231892180231
# Test cross entropy:
# Cross entropy:  0.6218914781184401
# EPOCH NUMBER:  33
# Train cross entropy:
# Cross entropy:  0.038239655051804385
# Test cross entropy:
# Cross entropy:  0.6267671520191112
# EPOCH NUMBER:  34
# Train cross entropy:
# Cross entropy:  0.03755312889154873
# Test cross entropy:
# Cross entropy:  0.6315077388554954
# EPOCH NUMBER:  35
# Train cross entropy:
# Cross entropy:  0.03691477840031531
# Test cross entropy:
# Cross entropy:  0.6360885331434555
# EPOCH NUMBER:  36
# Train cross entropy:
# Cross entropy:  0.03632299262369624
# Test cross entropy:
# Cross entropy:  0.6405109199307892
# EPOCH NUMBER:  37
# Train cross entropy:
# Cross entropy:  0.0357731047805786
# Test cross entropy:
# Cross entropy:  0.644792525473624
# EPOCH NUMBER:  38
# Train cross entropy:
# Cross entropy:  0.03525870092222371
# Test cross entropy:
# Cross entropy:  0.6489535135701523
# EPOCH NUMBER:  39
# Train cross entropy:
# Cross entropy:  0.03477271551202859
# Test cross entropy:
# Cross entropy:  0.6530100715609758
# EPOCH NUMBER:  40
# Train cross entropy:
# Cross entropy:  0.034308557113997454
# Test cross entropy:
# Cross entropy:  0.6569733058238778
# EPOCH NUMBER:  41
# Train cross entropy:
# Cross entropy:  0.0338613320145236
# Test cross entropy:
# Cross entropy:  0.6608517954474461
# EPOCH NUMBER:  42
# Train cross entropy:
# Cross entropy:  0.03342872050662748
# Test cross entropy:
# Cross entropy:  0.6646543040456897
# EPOCH NUMBER:  43
# Train cross entropy:
# Cross entropy:  0.033011247754463666
# Test cross entropy:
# Cross entropy:  0.6683872532907397
# EPOCH NUMBER:  44
# Train cross entropy:
# Cross entropy:  0.03261173987372235
# Test cross entropy:
# Cross entropy:  0.6720480313478966
# EPOCH NUMBER:  45
# Train cross entropy:
# Cross entropy:  0.03223313880697684
# Test cross entropy:
# Cross entropy:  0.6756225309075505
# EPOCH NUMBER:  46
# Train cross entropy:
# Cross entropy:  0.03187501457183029
# Test cross entropy:
# Cross entropy:  0.6790907751615151
# EPOCH NUMBER:  47
# Train cross entropy:
# Cross entropy:  0.031533679286583516
# Test cross entropy:
# Cross entropy:  0.6824381185206767
# EPOCH NUMBER:  48
# Train cross entropy:
# Cross entropy:  0.03120624243716424
# Test cross entropy:
# Cross entropy:  0.6856617950369917
# EPOCH NUMBER:  49
# Train cross entropy:
# Cross entropy:  0.030891136855422732
# Test cross entropy:
# Cross entropy:  0.6887646782509103
# EPOCH NUMBER:  50
# Train cross entropy:
# Cross entropy:  0.030586434080233673
# Test cross entropy:
# Cross entropy:  0.6917480446185202
# EPOCH NUMBER:  51
# Train cross entropy:
# Cross entropy:  0.030290806141459858
# Test cross entropy:
# Cross entropy:  0.6946166449395977
# EPOCH NUMBER:  52
# Train cross entropy:
# Cross entropy:  0.03000423407276803
# Test cross entropy:
# Cross entropy:  0.6973877426267526
# EPOCH NUMBER:  53
# Train cross entropy:
# Cross entropy:  0.029726753314304664
# Test cross entropy:
# Cross entropy:  0.7000908577481998
# EPOCH NUMBER:  54
# Train cross entropy:
# Cross entropy:  0.02945787244635938
# Test cross entropy:
# Cross entropy:  0.7027590635404951
# EPOCH NUMBER:  55
# Train cross entropy:
# Cross entropy:  0.02919719061877842
# Test cross entropy:
# Cross entropy:  0.7054217548082575
# EPOCH NUMBER:  56
# Train cross entropy:
# Cross entropy:  0.028944617703689775
# Test cross entropy:
# Cross entropy:  0.7081042364996889
# EPOCH NUMBER:  57
# Train cross entropy:
# Cross entropy:  0.02870018402757743
# Test cross entropy:
# Cross entropy:  0.7108287108724103
# EPOCH NUMBER:  58
# Train cross entropy:
# Cross entropy:  0.02846405332992106
# Test cross entropy:
# Cross entropy:  0.7136105596752589
# EPOCH NUMBER:  59
# Train cross entropy:
# Cross entropy:  0.028236731612946226
# Test cross entropy:
# Cross entropy:  0.7164538735441157
# EPOCH NUMBER:  60
# Train cross entropy:
# Cross entropy:  0.0280188513050279
# Test cross entropy:
# Cross entropy:  0.7193498935186803
# EPOCH NUMBER:  61
# Train cross entropy:
# Cross entropy:  0.027809652353616057
# Test cross entropy:
# Cross entropy:  0.7222730094543397
# EPOCH NUMBER:  62
# Train cross entropy:
# Cross entropy:  0.02760509325360455
# Test cross entropy:
# Cross entropy:  0.7251772885837787
# EPOCH NUMBER:  63
# Train cross entropy:
# Cross entropy:  0.02740036713230922
# Test cross entropy:
# Cross entropy:  0.7280079029889238
# EPOCH NUMBER:  64
# Train cross entropy:
# Cross entropy:  0.027197037084853357
# Test cross entropy:
# Cross entropy:  0.7307191176207064
# EPOCH NUMBER:  65
# Train cross entropy:
# Cross entropy:  0.027001780959950893
# Test cross entropy:
# Cross entropy:  0.7332885677441258
# EPOCH NUMBER:  66
# Train cross entropy:
# Cross entropy:  0.02681792165012704
# Test cross entropy:
# Cross entropy:  0.7357270400145691
# EPOCH NUMBER:  67
# Train cross entropy:
# Cross entropy:  0.026644715400084132
# Test cross entropy:
# Cross entropy:  0.7380565730351301
# EPOCH NUMBER:  68
# Train cross entropy:
# Cross entropy:  0.02648048845233386
# Test cross entropy:
# Cross entropy:  0.74029408179719
# EPOCH NUMBER:  69
# Train cross entropy:
# Cross entropy:  0.02632386082173155
# Test cross entropy:
# Cross entropy:  0.7424527338985362
# EPOCH NUMBER:  70
# Train cross entropy:
# Cross entropy:  0.02617381001499173
# Test cross entropy:
# Cross entropy:  0.7445434828909602
# EPOCH NUMBER:  71
# Train cross entropy:
# Cross entropy:  0.026029579521689796
# Test cross entropy:
# Cross entropy:  0.746575280484707
# EPOCH NUMBER:  72
# Train cross entropy:
# Cross entropy:  0.025890605519713752
# Test cross entropy:
# Cross entropy:  0.7485552886756737
# EPOCH NUMBER:  73
# Train cross entropy:
# Cross entropy:  0.02575645615656003
# Test cross entropy:
# Cross entropy:  0.7504891778146718
# EPOCH NUMBER:  74
# Train cross entropy:
# Cross entropy:  0.025626783223941903
# Test cross entropy:
# Cross entropy:  0.752381392394001
# EPOCH NUMBER:  75
# Train cross entropy:
# Cross entropy:  0.025501289168235096
# Test cross entropy:
# Cross entropy:  0.7542353600220013
# EPOCH NUMBER:  76
# Train cross entropy:
# Cross entropy:  0.025379707856652615
# Test cross entropy:
# Cross entropy:  0.7560536681621506
# EPOCH NUMBER:  77
# Train cross entropy:
# Cross entropy:  0.02526179467476482
# Test cross entropy:
# Cross entropy:  0.7578382314991038
# EPOCH NUMBER:  78
# Train cross entropy:
# Cross entropy:  0.025147321845173515
# Test cross entropy:
# Cross entropy:  0.7595904579209305
# EPOCH NUMBER:  79
# Train cross entropy:
# Cross entropy:  0.025036076446902922
# Test cross entropy:
# Cross entropy:  0.7613114097987553
# EPOCH NUMBER:  80
# Train cross entropy:
# Cross entropy:  0.024927859912880233
# Test cross entropy:
# Cross entropy:  0.7630019521996158
# EPOCH NUMBER:  81
# Train cross entropy:
# Cross entropy:  0.024822488358165085
# Test cross entropy:
# Cross entropy:  0.7646628797381665
# EPOCH NUMBER:  82
# Train cross entropy:
# Cross entropy:  0.0247197931916858
# Test cross entropy:
# Cross entropy:  0.7662950170448842
# EPOCH NUMBER:  83
# Train cross entropy:
# Cross entropy:  0.02461962144083727
# Test cross entropy:
# Cross entropy:  0.7678992920353799
# EPOCH NUMBER:  84
# Train cross entropy:
# Cross entropy:  0.024521835253017096
# Test cross entropy:
# Cross entropy:  0.7694767841428619
# EPOCH NUMBER:  85
# Train cross entropy:
# Cross entropy:  0.02442631014966103
# Test cross entropy:
# Cross entropy:  0.7710287499011407
# EPOCH NUMBER:  86
# Train cross entropy:
# Cross entropy:  0.024332931775104816
# Test cross entropy:
# Cross entropy:  0.7725566250981812
# EPOCH NUMBER:  87
# Train cross entropy:
# Cross entropy:  0.02424159114708161
# Test cross entropy:
# Cross entropy:  0.7740619965082519
# EPOCH NUMBER:  88
# Train cross entropy:
# Cross entropy:  0.024152178918046992
# Test cross entropy:
# Cross entropy:  0.7755465287418667
# EPOCH NUMBER:  89
# Train cross entropy:
# Cross entropy:  0.024064580076887228
# Test cross entropy:
# Cross entropy:  0.7770118272592832
# EPOCH NUMBER:  90
# Train cross entropy:
# Cross entropy:  0.023978671860543366
# Test cross entropy:
# Cross entropy:  0.7784592247348425
# EPOCH NUMBER:  91
# Train cross entropy:
# Cross entropy:  0.02389432875346182
# Test cross entropy:
# Cross entropy:  0.779889504861131
# EPOCH NUMBER:  92
# Train cross entropy:
# Cross entropy:  0.023811437532520872
# Test cross entropy:
# Cross entropy:  0.7813026310642917
# EPOCH NUMBER:  93
# Train cross entropy:
# Cross entropy:  0.02372992021347841
# Test cross entropy:
# Cross entropy:  0.7826976120334287
# EPOCH NUMBER:  94
# Train cross entropy:
# Cross entropy:  0.02364975463454763
# Test cross entropy:
# Cross entropy:  0.7840726576578442
# EPOCH NUMBER:  95
# Train cross entropy:
# Cross entropy:  0.02357097895519647
# Test cross entropy:
# Cross entropy:  0.785425687320549
# EPOCH NUMBER:  96
# Train cross entropy:
# Cross entropy:  0.02349367493086759
# Test cross entropy:
# Cross entropy:  0.7867550485727599
# EPOCH NUMBER:  97
# Train cross entropy:
# Cross entropy:  0.023417939347390674
# Test cross entropy:
# Cross entropy:  0.7880601290255402
# EPOCH NUMBER:  98
# Train cross entropy:
# Cross entropy:  0.02334385857483113
# Test cross entropy:
# Cross entropy:  0.7893415756819605
# EPOCH NUMBER:  99
# Train cross entropy:
# Cross entropy:  0.023271494561600537
# Test cross entropy:
# Cross entropy:  0.7906010750835377

# %%
epochs = [i for i in range(1, 101)]
plt.title('Learning rate 0.1 for 100 epochs')
plt.xlabel("Epochs")
plt.ylabel("cross-entropy")
plt.plot(epochs, test_cross, color='green', label='Test cross-entropy')
plt.plot(epochs, train_cross, color='red', label='Training cross-entropy')
plt.legend()
plt.show()

# %%
a, b, test_cross, train_cross = SGD_Procedure(df_train=large_train, df_test=large_test, epochs=100,
                                              learning_rate=0.001, num_classes=10, num_features=128, 
                                              num_hidden=50, weight_init_method="RANDOM")
# Out:
# EPOCH NUMBER:  0
# Train cross entropy:
# Cross entropy:  2.2672504215853975
# Test cross entropy:
# Cross entropy:  2.3118177599896916
# EPOCH NUMBER:  1
# Train cross entropy:
# Cross entropy:  2.1395257791751505
# Test cross entropy:
# Cross entropy:  2.215509405649345
# EPOCH NUMBER:  2
# Train cross entropy:
# Cross entropy:  1.9131241790357436
# Test cross entropy:
# Cross entropy:  2.030382132340386
# EPOCH NUMBER:  3
# Train cross entropy:
# Cross entropy:  1.6824226026648619
# Test cross entropy:
# Cross entropy:  1.7881817997696685
# EPOCH NUMBER:  4
# Train cross entropy:
# Cross entropy:  1.4965015437400342
# Test cross entropy:
# Cross entropy:  1.5893147415084488
# EPOCH NUMBER:  5
# Train cross entropy:
# Cross entropy:  1.3423258388134198
# Test cross entropy:
# Cross entropy:  1.4293095636028006
# EPOCH NUMBER:  6
# Train cross entropy:
# Cross entropy:  1.212633804621776
# Test cross entropy:
# Cross entropy:  1.2958355009341336
# EPOCH NUMBER:  7
# Train cross entropy:
# Cross entropy:  1.1060835273185912
# Test cross entropy:
# Cross entropy:  1.1860263123522627
# EPOCH NUMBER:  8
# Train cross entropy:
# Cross entropy:  1.0206002184780056
# Test cross entropy:
# Cross entropy:  1.098001962368221
# EPOCH NUMBER:  9
# Train cross entropy:
# Cross entropy:  0.9527167153249927
# Test cross entropy:
# Cross entropy:  1.0283290922919108
# EPOCH NUMBER:  10
# Train cross entropy:
# Cross entropy:  0.8987747669062995
# Test cross entropy:
# Cross entropy:  0.9732122883667855
# EPOCH NUMBER:  11
# Train cross entropy:
# Cross entropy:  0.8555420493382133
# Test cross entropy:
# Cross entropy:  0.9292976487620073
# EPOCH NUMBER:  12
# Train cross entropy:
# Cross entropy:  0.8203840018521056
# Test cross entropy:
# Cross entropy:  0.893853023863046
# EPOCH NUMBER:  13
# Train cross entropy:
# Cross entropy:  0.7912667238657078
# Test cross entropy:
# Cross entropy:  0.8647565857871502
# EPOCH NUMBER:  14
# Train cross entropy:
# Cross entropy:  0.7666798523782444
# Test cross entropy:
# Cross entropy:  0.8404216843350075
# EPOCH NUMBER:  15
# Train cross entropy:
# Cross entropy:  0.7455276132365933
# Test cross entropy:
# Cross entropy:  0.8196922042467396
# EPOCH NUMBER:  16
# Train cross entropy:
# Cross entropy:  0.7270224324684996
# Test cross entropy:
# Cross entropy:  0.8017362996804809
# EPOCH NUMBER:  17
# Train cross entropy:
# Cross entropy:  0.7105974536316224
# Test cross entropy:
# Cross entropy:  0.7859560447447386
# EPOCH NUMBER:  18
# Train cross entropy:
# Cross entropy:  0.6958409761354664
# Test cross entropy:
# Cross entropy:  0.77191824398006
# EPOCH NUMBER:  19
# Train cross entropy:
# Cross entropy:  0.6824497360684734
# Test cross entropy:
# Cross entropy:  0.7593045502112941
# EPOCH NUMBER:  20
# Train cross entropy:
# Cross entropy:  0.6701964554419139
# Test cross entropy:
# Cross entropy:  0.7478766795263794
# EPOCH NUMBER:  21
# Train cross entropy:
# Cross entropy:  0.6589075391509968
# Test cross entropy:
# Cross entropy:  0.7374525507224142
# EPOCH NUMBER:  22
# Train cross entropy:
# Cross entropy:  0.648447766139122
# Test cross entropy:
# Cross entropy:  0.7278900122585688
# EPOCH NUMBER:  23
# Train cross entropy:
# Cross entropy:  0.6387097341372268
# Test cross entropy:
# Cross entropy:  0.7190757289048368
# EPOCH NUMBER:  24
# Train cross entropy:
# Cross entropy:  0.6296065230625449
# Test cross entropy:
# Cross entropy:  0.7109175444496666
# EPOCH NUMBER:  25
# Train cross entropy:
# Cross entropy:  0.6210665434897414
# Test cross entropy:
# Cross entropy:  0.7033391817277257
# EPOCH NUMBER:  26
# Train cross entropy:
# Cross entropy:  0.6130298783876623
# Test cross entropy:
# Cross entropy:  0.6962765189854916
# EPOCH NUMBER:  27
# Train cross entropy:
# Cross entropy:  0.6054456545991426
# Test cross entropy:
# Cross entropy:  0.6896749360185752
# EPOCH NUMBER:  28
# Train cross entropy:
# Cross entropy:  0.5982701316235434
# Test cross entropy:
# Cross entropy:  0.683487392332446
# EPOCH NUMBER:  29
# Train cross entropy:
# Cross entropy:  0.5914652950634773
# Test cross entropy:
# Cross entropy:  0.6776730109450259
# EPOCH NUMBER:  30
# Train cross entropy:
# Cross entropy:  0.5849978082984462
# Test cross entropy:
# Cross entropy:  0.67219601497606
# EPOCH NUMBER:  31
# Train cross entropy:
# Cross entropy:  0.5788382203007408
# Test cross entropy:
# Cross entropy:  0.6670249129965254
# EPOCH NUMBER:  32
# Train cross entropy:
# Cross entropy:  0.5729603576771518
# Test cross entropy:
# Cross entropy:  0.6621318618329333
# EPOCH NUMBER:  33
# Train cross entropy:
# Cross entropy:  0.5673408499152757
# Test cross entropy:
# Cross entropy:  0.657492157666925
# EPOCH NUMBER:  34
# Train cross entropy:
# Cross entropy:  0.561958751536698
# Test cross entropy:
# Cross entropy:  0.6530838213809256
# EPOCH NUMBER:  35
# Train cross entropy:
# Cross entropy:  0.5567952353602649
# Test cross entropy:
# Cross entropy:  0.6488872544578419
# EPOCH NUMBER:  36
# Train cross entropy:
# Cross entropy:  0.5518333386012609
# Test cross entropy:
# Cross entropy:  0.6448849488459729
# EPOCH NUMBER:  37
# Train cross entropy:
# Cross entropy:  0.5470577489033698
# Test cross entropy:
# Cross entropy:  0.641061239060621
# EPOCH NUMBER:  38
# Train cross entropy:
# Cross entropy:  0.5424546212001264
# Test cross entropy:
# Cross entropy:  0.6374020881101344
# EPOCH NUMBER:  39
# Train cross entropy:
# Cross entropy:  0.538011418958459
# Test cross entropy:
# Cross entropy:  0.6338949010954525
# EPOCH NUMBER:  40
# Train cross entropy:
# Cross entropy:  0.5337167751909723
# Test cross entropy:
# Cross entropy:  0.6305283618806643
# EPOCH NUMBER:  41
# Train cross entropy:
# Cross entropy:  0.5295603698783768
# Test cross entropy:
# Cross entropy:  0.6272922893035402
# EPOCH NUMBER:  42
# Train cross entropy:
# Cross entropy:  0.52553282129803
# Test cross entropy:
# Cross entropy:  0.6241775101490016
# EPOCH NUMBER:  43
# Train cross entropy:
# Cross entropy:  0.521625589337712
# Test cross entropy:
# Cross entropy:  0.6211757466509031
# EPOCH NUMBER:  44
# Train cross entropy:
# Cross entropy:  0.5178308892754253
# Test cross entropy:
# Cross entropy:  0.6182795166873086
# EPOCH NUMBER:  45
# Train cross entropy:
# Cross entropy:  0.5141416147873884
# Test cross entropy:
# Cross entropy:  0.6154820451364892
# EPOCH NUMBER:  46
# Train cross entropy:
# Cross entropy:  0.5105512691482926
# Test cross entropy:
# Cross entropy:  0.6127771850943174
# EPOCH NUMBER:  47
# Train cross entropy:
# Cross entropy:  0.5070539037370954
# Test cross entropy:
# Cross entropy:  0.6101593478378826
# EPOCH NUMBER:  48
# Train cross entropy:
# Cross entropy:  0.5036440630755985
# Test cross entropy:
# Cross entropy:  0.6076234405681259
# EPOCH NUMBER:  49
# Train cross entropy:
# Cross entropy:  0.500316735717187
# Test cross entropy:
# Cross entropy:  0.6051648110852021
# EPOCH NUMBER:  50
# Train cross entropy:
# Cross entropy:  0.4970673103767795
# Test cross entropy:
# Cross entropy:  0.6027791986506238
# EPOCH NUMBER:  51
# Train cross entropy:
# Cross entropy:  0.4938915367551603
# Test cross entropy:
# Cross entropy:  0.6004626903747917
# EPOCH NUMBER:  52
# Train cross entropy:
# Cross entropy:  0.49078549056462323
# Test cross entropy:
# Cross entropy:  0.5982116825407514
# EPOCH NUMBER:  53
# Train cross entropy:
# Cross entropy:  0.4877455423103999
# Test cross entropy:
# Cross entropy:  0.5960228463375201
# EPOCH NUMBER:  54
# Train cross entropy:
# Cross entropy:  0.4847683294250945
# Test cross entropy:
# Cross entropy:  0.5938930975310647
# EPOCH NUMBER:  55
# Train cross entropy:
# Cross entropy:  0.4818507313922319
# Test cross entropy:
# Cross entropy:  0.5918195696493949
# EPOCH NUMBER:  56
# Train cross entropy:
# Cross entropy:  0.4789898475306658
# Test cross entropy:
# Cross entropy:  0.5897995903013662
# EPOCH NUMBER:  57
# Train cross entropy:
# Cross entropy:  0.47618297714440916
# Test cross entropy:
# Cross entropy:  0.5878306602874714
# EPOCH NUMBER:  58
# Train cross entropy:
# Cross entropy:  0.47342760177268106
# Test cross entropy:
# Cross entropy:  0.5859104351957526
# EPOCH NUMBER:  59
# Train cross entropy:
# Cross entropy:  0.4707213693028248
# Test cross entropy:
# Cross entropy:  0.5840367092074584
# EPOCH NUMBER:  60
# Train cross entropy:
# Cross entropy:  0.46806207973433167
# Test cross entropy:
# Cross entropy:  0.5822074008655838
# EPOCH NUMBER:  61
# Train cross entropy:
# Cross entropy:  0.4654476724056363
# Test cross entropy:
# Cross entropy:  0.5804205405852378
# EPOCH NUMBER:  62
# Train cross entropy:
# Cross entropy:  0.4628762145166991
# Test cross entropy:
# Cross entropy:  0.5786742597081502
# EPOCH NUMBER:  63
# Train cross entropy:
# Cross entropy:  0.4603458907997479
# Test cross entropy:
# Cross entropy:  0.5769667809247537
# EPOCH NUMBER:  64
# Train cross entropy:
# Cross entropy:  0.4578549942080113
# Test cross entropy:
# Cross entropy:  0.5752964099063419
# EPOCH NUMBER:  65
# Train cross entropy:
# Cross entropy:  0.45540191750793374
# Test cross entropy:
# Cross entropy:  0.5736615280069919
# EPOCH NUMBER:  66
# Train cross entropy:
# Cross entropy:  0.4529851456743141
# Test cross entropy:
# Cross entropy:  0.572060585910368
# EPOCH NUMBER:  67
# Train cross entropy:
# Cross entropy:  0.45060324900018334
# Test cross entropy:
# Cross entropy:  0.570492098110394
# EPOCH NUMBER:  68
# Train cross entropy:
# Cross entropy:  0.4482548768441344
# Test cross entropy:
# Cross entropy:  0.5689546381271541
# EPOCH NUMBER:  69
# Train cross entropy:
# Cross entropy:  0.44593875194737076
# Test cross entropy:
# Cross entropy:  0.5674468343704651
# EPOCH NUMBER:  70
# Train cross entropy:
# Cross entropy:  0.4436536652610639
# Test cross entropy:
# Cross entropy:  0.565967366573396
# EPOCH NUMBER:  71
# Train cross entropy:
# Cross entropy:  0.4413984712318406
# Test cross entropy:
# Cross entropy:  0.5645149627267686
# EPOCH NUMBER:  72
# Train cross entropy:
# Cross entropy:  0.43917208349945497
# Test cross entropy:
# Cross entropy:  0.5630883964533936
# EPOCH NUMBER:  73
# Train cross entropy:
# Cross entropy:  0.43697347096608435
# Test cross entropy:
# Cross entropy:  0.5616864847676536
# EPOCH NUMBER:  74
# Train cross entropy:
# Cross entropy:  0.43480165420130495
# Test cross entropy:
# Cross entropy:  0.5603080861720178
# EPOCH NUMBER:  75
# Train cross entropy:
# Cross entropy:  0.43265570215077226
# Test cross entropy:
# Cross entropy:  0.558952099047359
# EPOCH NUMBER:  76
# Train cross entropy:
# Cross entropy:  0.43053472912004337
# Test cross entropy:
# Cross entropy:  0.5576174602985087
# EPOCH NUMBER:  77
# Train cross entropy:
# Cross entropy:  0.42843789200791976
# Test cross entropy:
# Cross entropy:  0.5563031442204863
# EPOCH NUMBER:  78
# Train cross entropy:
# Cross entropy:  0.4263643877662325
# Test cross entropy:
# Cross entropy:  0.5550081615542728
# EPOCH NUMBER:  79
# Train cross entropy:
# Cross entropy:  0.42431345106521484
# Test cross entropy:
# Cross entropy:  0.5537315587039898
# EPOCH NUMBER:  80
# Train cross entropy:
# Cross entropy:  0.4222843521455508
# Test cross entropy:
# Cross entropy:  0.5524724170899011
# EPOCH NUMBER:  81
# Train cross entropy:
# Cross entropy:  0.4202763948399221
# Test cross entropy:
# Cross entropy:  0.551229852613879
# EPOCH NUMBER:  82
# Train cross entropy:
# Cross entropy:  0.41828891474841623
# Test cross entropy:
# Cross entropy:  0.5500030152159083
# EPOCH NUMBER:  83
# Train cross entropy:
# Cross entropy:  0.4163212775535567
# Test cross entropy:
# Cross entropy:  0.5487910885018985
# EPOCH NUMBER:  84
# Train cross entropy:
# Cross entropy:  0.41437287746198265
# Test cross entropy:
# Cross entropy:  0.5475932894245968
# EPOCH NUMBER:  85
# Train cross entropy:
# Cross entropy:  0.41244313576097036
# Test cross entropy:
# Cross entropy:  0.5464088680008011
# EPOCH NUMBER:  86
# Train cross entropy:
# Cross entropy:  0.4105314994790564
# Test cross entropy:
# Cross entropy:  0.5452371070493792
# EPOCH NUMBER:  87
# Train cross entropy:
# Cross entropy:  0.4086374401410056
# Test cross entropy:
# Cross entropy:  0.5440773219358951
# EPOCH NUMBER:  88
# Train cross entropy:
# Cross entropy:  0.4067604526082767
# Test cross entropy:
# Cross entropy:  0.5429288603109111
# EPOCH NUMBER:  89
# Train cross entropy:
# Cross entropy:  0.40490005399697804
# Test cross entropy:
# Cross entropy:  0.5417911018303369
# EPOCH NUMBER:  90
# Train cross entropy:
# Cross entropy:  0.4030557826660676
# Test cross entropy:
# Cross entropy:  0.5406634578475225
# EPOCH NUMBER:  91
# Train cross entropy:
# Cross entropy:  0.4012271972692629
# Test cross entropy:
# Cross entropy:  0.5395453710681833
# EPOCH NUMBER:  92
# Train cross entropy:
# Cross entropy:  0.3994138758647637
# Test cross entropy:
# Cross entropy:  0.5384363151606513
# EPOCH NUMBER:  93
# Train cross entropy:
# Cross entropy:  0.3976154150774776
# Test cross entropy:
# Cross entropy:  0.5373357943154168
# EPOCH NUMBER:  94
# Train cross entropy:
# Cross entropy:  0.3958314293089657
# Test cross entropy:
# Cross entropy:  0.536243342749402
# EPOCH NUMBER:  95
# Train cross entropy:
# Cross entropy:  0.3940615499908049
# Test cross entropy:
# Cross entropy:  0.5351585241518778
# EPOCH NUMBER:  96
# Train cross entropy:
# Cross entropy:  0.3923054248774945
# Test cross entropy:
# Cross entropy:  0.5340809310704105
# EPOCH NUMBER:  97
# Train cross entropy:
# Cross entropy:  0.39056271737542375
# Test cross entropy:
# Cross entropy:  0.5330101842366111
# EPOCH NUMBER:  98
# Train cross entropy:
# Cross entropy:  0.3888331059047713
# Test cross entropy:
# Cross entropy:  0.531945931832807
# EPOCH NUMBER:  99
# Train cross entropy:
# Cross entropy:  0.38711628329152437
# Test cross entropy:
# Cross entropy:  0.5308878487019874

# %%
epochs = [i for i in range(1, 101)]
plt.title('Learning rate 0.001 for 100 epochs')
plt.xlabel("Epochs")
plt.ylabel("cross-entropy")
plt.plot(epochs, test_cross, color='green', label='Test cross-entropy')
plt.plot(epochs, train_cross, color='red', label='Training cross-entropy')
plt.legend()
plt.show()

# %%
final_values_test = []
final_values_train = []

for num in [5, 20, 50, 100, 200]:
  a, b, test_cross, train_cross = SGD_Procedure(df_train=large_train, df_test=large_test, epochs=100,
                                              learning_rate=0.01, num_classes=10, num_features=128, 
                                              num_hidden=num, weight_init_method="RANDOM")
  final_values_test.append(test_cross)
  final_values_train.append(train_cross)
# Out:
# EPOCH NUMBER:  0
# Train cross entropy:
# Cross entropy:  2.033618928699117
# Test cross entropy:
# Cross entropy:  2.3078362492885685
# EPOCH NUMBER:  1
# Train cross entropy:
# Cross entropy:  1.4447285662351472
# Test cross entropy:
# Cross entropy:  1.6479366342123303
# EPOCH NUMBER:  2
# Train cross entropy:
# Cross entropy:  1.1348472184848852
# Test cross entropy:
# Cross entropy:  1.2904074452982963
# EPOCH NUMBER:  3
# Train cross entropy:
# Cross entropy:  0.9572616779136965
# Test cross entropy:
# Cross entropy:  1.0918672943852963
# EPOCH NUMBER:  4
# Train cross entropy:
# Cross entropy:  0.8293092239058021
# Test cross entropy:
# Cross entropy:  0.9527147410253932
# EPOCH NUMBER:  5
# Train cross entropy:
# Cross entropy:  0.7541477269276285
# Test cross entropy:
# Cross entropy:  0.8607955894792284
# EPOCH NUMBER:  6
# Train cross entropy:
# Cross entropy:  0.7124490416321178
# Test cross entropy:
# Cross entropy:  0.8132230802382551
# EPOCH NUMBER:  7
# Train cross entropy:
# Cross entropy:  0.686569237250209
# Test cross entropy:
# Cross entropy:  0.7863071111192567
# EPOCH NUMBER:  8
# Train cross entropy:
# Cross entropy:  0.6688313772421159
# Test cross entropy:
# Cross entropy:  0.7694668765372894
# EPOCH NUMBER:  9
# Train cross entropy:
# Cross entropy:  0.6558054724378757
# Test cross entropy:
# Cross entropy:  0.758176228486888
# EPOCH NUMBER:  10
# Train cross entropy:
# Cross entropy:  0.6457805802472788
# Test cross entropy:
# Cross entropy:  0.7501793809402825
# EPOCH NUMBER:  11
# Train cross entropy:
# Cross entropy:  0.6378166058064885
# Test cross entropy:
# Cross entropy:  0.7441680801369784
# EPOCH NUMBER:  12
# Train cross entropy:
# Cross entropy:  0.6313309095584865
# Test cross entropy:
# Cross entropy:  0.7393423861359104
# EPOCH NUMBER:  13
# Train cross entropy:
# Cross entropy:  0.6259275515792605
# Test cross entropy:
# Cross entropy:  0.7352559263582702
# EPOCH NUMBER:  14
# Train cross entropy:
# Cross entropy:  0.6213309165229102
# Test cross entropy:
# Cross entropy:  0.7316752121214902
# EPOCH NUMBER:  15
# Train cross entropy:
# Cross entropy:  0.6173447686665534
# Test cross entropy:
# Cross entropy:  0.7284719738347978
# EPOCH NUMBER:  16
# Train cross entropy:
# Cross entropy:  0.6138272577205649
# Test cross entropy:
# Cross entropy:  0.7255737699518238
# EPOCH NUMBER:  17
# Train cross entropy:
# Cross entropy:  0.6106776450169311
# Test cross entropy:
# Cross entropy:  0.7229451457880693
# EPOCH NUMBER:  18
# Train cross entropy:
# Cross entropy:  0.6078270782584255
# Test cross entropy:
# Cross entropy:  0.7205739800365523
# EPOCH NUMBER:  19
# Train cross entropy:
# Cross entropy:  0.6052298303101763
# Test cross entropy:
# Cross entropy:  0.7184517079526356
# EPOCH NUMBER:  20
# Train cross entropy:
# Cross entropy:  0.6028545512831341
# Test cross entropy:
# Cross entropy:  0.7165585804324935
# EPOCH NUMBER:  21
# Train cross entropy:
# Cross entropy:  0.600676899987656
# Test cross entropy:
# Cross entropy:  0.7148676144832204
# EPOCH NUMBER:  22
# Train cross entropy:
# Cross entropy:  0.5986752438081776
# Test cross entropy:
# Cross entropy:  0.7133557482220069
# EPOCH NUMBER:  23
# Train cross entropy:
# Cross entropy:  0.596829469819243
# Test cross entropy:
# Cross entropy:  0.7120082782036967
# EPOCH NUMBER:  24
# Train cross entropy:
# Cross entropy:  0.595121205175936
# Test cross entropy:
# Cross entropy:  0.7108171041122512
# EPOCH NUMBER:  25
# Train cross entropy:
# Cross entropy:  0.5935340938234116
# Test cross entropy:
# Cross entropy:  0.7097773927200964
# EPOCH NUMBER:  26
# Train cross entropy:
# Cross entropy:  0.5920538052553909
# Test cross entropy:
# Cross entropy:  0.7088848405268644
# EPOCH NUMBER:  27
# Train cross entropy:
# Cross entropy:  0.5906678892975413
# Test cross entropy:
# Cross entropy:  0.7081340203510162
# EPOCH NUMBER:  28
# Train cross entropy:
# Cross entropy:  0.5893655843166817
# Test cross entropy:
# Cross entropy:  0.7075177335778239
# EPOCH NUMBER:  29
# Train cross entropy:
# Cross entropy:  0.5881376228738214
# Test cross entropy:
# Cross entropy:  0.7070270625334864
# EPOCH NUMBER:  30
# Train cross entropy:
# Cross entropy:  0.5869760562375522
# Test cross entropy:
# Cross entropy:  0.7066517710544834
# EPOCH NUMBER:  31
# Train cross entropy:
# Cross entropy:  0.5858741086578352
# Test cross entropy:
# Cross entropy:  0.7063807983251809
# EPOCH NUMBER:  32
# Train cross entropy:
# Cross entropy:  0.5848260626768768
# Test cross entropy:
# Cross entropy:  0.7062027246441022
# EPOCH NUMBER:  33
# Train cross entropy:
# Cross entropy:  0.5838271707214655
# Test cross entropy:
# Cross entropy:  0.7061061817500318
# EPOCH NUMBER:  34
# Train cross entropy:
# Cross entropy:  0.5828735847975834
# Test cross entropy:
# Cross entropy:  0.7060802184455345
# EPOCH NUMBER:  35
# Train cross entropy:
# Cross entropy:  0.5819622905139292
# Test cross entropy:
# Cross entropy:  0.7061146321645583
# EPOCH NUMBER:  36
# Train cross entropy:
# Cross entropy:  0.5810910210288951
# Test cross entropy:
# Cross entropy:  0.7062002638658758
# EPOCH NUMBER:  37
# Train cross entropy:
# Cross entropy:  0.5802581190182283
# Test cross entropy:
# Cross entropy:  0.7063292392443552
# EPOCH NUMBER:  38
# Train cross entropy:
# Cross entropy:  0.5794623300709387
# Test cross entropy:
# Cross entropy:  0.706495125306566
# EPOCH NUMBER:  39
# Train cross entropy:
# Cross entropy:  0.5787025552656975
# Test cross entropy:
# Cross entropy:  0.7066929688342204
# EPOCH NUMBER:  40
# Train cross entropy:
# Cross entropy:  0.5779776322304915
# Test cross entropy:
# Cross entropy:  0.7069191986256915
# EPOCH NUMBER:  41
# Train cross entropy:
# Cross entropy:  0.5772862103734546
# Test cross entropy:
# Cross entropy:  0.7071713871682057
# EPOCH NUMBER:  42
# Train cross entropy:
# Cross entropy:  0.5766267384760563
# Test cross entropy:
# Cross entropy:  0.7074478822730066
# EPOCH NUMBER:  43
# Train cross entropy:
# Cross entropy:  0.5759975343894326
# Test cross entropy:
# Cross entropy:  0.7077473705150712
# EPOCH NUMBER:  44
# Train cross entropy:
# Cross entropy:  0.5753968880131323
# Test cross entropy:
# Cross entropy:  0.7080684934990615
# EPOCH NUMBER:  45
# Train cross entropy:
# Cross entropy:  0.5748231554154134
# Test cross entropy:
# Cross entropy:  0.7084096240348197
# EPOCH NUMBER:  46
# Train cross entropy:
# Cross entropy:  0.5742748185348007
# Test cross entropy:
# Cross entropy:  0.7087688239141824
# EPOCH NUMBER:  47
# Train cross entropy:
# Cross entropy:  0.5737505034968895
# Test cross entropy:
# Cross entropy:  0.7091439313436447
# EPOCH NUMBER:  48
# Train cross entropy:
# Cross entropy:  0.5732489662102319
# Test cross entropy:
# Cross entropy:  0.7095327088326633
# EPOCH NUMBER:  49
# Train cross entropy:
# Cross entropy:  0.5727690619227755
# Test cross entropy:
# Cross entropy:  0.7099329976395233
# EPOCH NUMBER:  50
# Train cross entropy:
# Cross entropy:  0.5723097147178577
# Test cross entropy:
# Cross entropy:  0.710342841016067
# EPOCH NUMBER:  51
# Train cross entropy:
# Cross entropy:  0.5718698964772603
# Test cross entropy:
# Cross entropy:  0.7107605509549026
# EPOCH NUMBER:  52
# Train cross entropy:
# Cross entropy:  0.5714486172330379
# Test cross entropy:
# Cross entropy:  0.7111847102152264
# EPOCH NUMBER:  53
# Train cross entropy:
# Cross entropy:  0.5710449236081947
# Test cross entropy:
# Cross entropy:  0.7116141225871069
# EPOCH NUMBER:  54
# Train cross entropy:
# Cross entropy:  0.5706579003771296
# Test cross entropy:
# Cross entropy:  0.7120477388799202
# EPOCH NUMBER:  55
# Train cross entropy:
# Cross entropy:  0.5702866713004783
# Test cross entropy:
# Cross entropy:  0.7124845861439016
# EPOCH NUMBER:  56
# Train cross entropy:
# Cross entropy:  0.5699303977605785
# Test cross entropy:
# Cross entropy:  0.7129237165822316
# EPOCH NUMBER:  57
# Train cross entropy:
# Cross entropy:  0.5695882758242119
# Test cross entropy:
# Cross entropy:  0.713364180076913
# EPOCH NUMBER:  58
# Train cross entropy:
# Cross entropy:  0.5692595332534869
# Test cross entropy:
# Cross entropy:  0.7138050166392104
# EPOCH NUMBER:  59
# Train cross entropy:
# Cross entropy:  0.5689434276653302
# Test cross entropy:
# Cross entropy:  0.7142452627252864
# EPOCH NUMBER:  60
# Train cross entropy:
# Cross entropy:  0.5686392461791347
# Test cross entropy:
# Cross entropy:  0.7146839656916496
# EPOCH NUMBER:  61
# Train cross entropy:
# Cross entropy:  0.5683463061853387
# Test cross entropy:
# Cross entropy:  0.7151202017061996
# EPOCH NUMBER:  62
# Train cross entropy:
# Cross entropy:  0.5680639565969572
# Test cross entropy:
# Cross entropy:  0.715553093520155
# EPOCH NUMBER:  63
# Train cross entropy:
# Cross entropy:  0.5677915790230621
# Test cross entropy:
# Cross entropy:  0.7159818256150068
# EPOCH NUMBER:  64
# Train cross entropy:
# Cross entropy:  0.5675285885215167
# Test cross entropy:
# Cross entropy:  0.7164056553441669
# EPOCH NUMBER:  65
# Train cross entropy:
# Cross entropy:  0.5672744337974349
# Test cross entropy:
# Cross entropy:  0.7168239196590767
# EPOCH NUMBER:  66
# Train cross entropy:
# Cross entropy:  0.5670285968549628
# Test cross entropy:
# Cross entropy:  0.7172360377179721
# EPOCH NUMBER:  67
# Train cross entropy:
# Cross entropy:  0.5667905921829398
# Test cross entropy:
# Cross entropy:  0.7176415100826593
# EPOCH NUMBER:  68
# Train cross entropy:
# Cross entropy:  0.5665599655805083
# Test cross entropy:
# Cross entropy:  0.7180399153576691
# EPOCH NUMBER:  69
# Train cross entropy:
# Cross entropy:  0.5663362927276361
# Test cross entropy:
# Cross entropy:  0.7184309050986663
# EPOCH NUMBER:  70
# Train cross entropy:
# Cross entropy:  0.5661191775923199
# Test cross entropy:
# Cross entropy:  0.7188141976944463
# EPOCH NUMBER:  71
# Train cross entropy:
# Cross entropy:  0.5659082507491977
# Test cross entropy:
# Cross entropy:  0.7191895717709196
# EPOCH NUMBER:  72
# Train cross entropy:
# Cross entropy:  0.5657031676675843
# Test cross entropy:
# Cross entropy:  0.7195568595141364
# EPOCH NUMBER:  73
# Train cross entropy:
# Cross entropy:  0.5655036070122881
# Test cross entropy:
# Cross entropy:  0.7199159401813576
# EPOCH NUMBER:  74
# Train cross entropy:
# Cross entropy:  0.5653092689884626
# Test cross entropy:
# Cross entropy:  0.7202667339701642
# EPOCH NUMBER:  75
# Train cross entropy:
# Cross entropy:  0.5651198737521993
# Test cross entropy:
# Cross entropy:  0.7206091963441957
# EPOCH NUMBER:  76
# Train cross entropy:
# Cross entropy:  0.5649351599011855
# Test cross entropy:
# Cross entropy:  0.7209433128654593
# EPOCH NUMBER:  77
# Train cross entropy:
# Cross entropy:  0.5647548830542617
# Test cross entropy:
# Cross entropy:  0.7212690945518226
# EPOCH NUMBER:  78
# Train cross entropy:
# Cross entropy:  0.5645788145246569
# Test cross entropy:
# Cross entropy:  0.7215865737589784
# EPOCH NUMBER:  79
# Train cross entropy:
# Cross entropy:  0.5644067400887944
# Test cross entropy:
# Cross entropy:  0.7218958005747186
# EPOCH NUMBER:  80
# Train cross entropy:
# Cross entropy:  0.5642384588504961
# Test cross entropy:
# Cross entropy:  0.7221968397066109
# EPOCH NUMBER:  81
# Train cross entropy:
# Cross entropy:  0.5640737821990062
# Test cross entropy:
# Cross entropy:  0.7224897678398748
# EPOCH NUMBER:  82
# Train cross entropy:
# Cross entropy:  0.5639125328582446
# Test cross entropy:
# Cross entropy:  0.7227746714390882
# EPOCH NUMBER:  83
# Train cross entropy:
# Cross entropy:  0.5637545440240171
# Test cross entropy:
# Cross entropy:  0.7230516449644285
# EPOCH NUMBER:  84
# Train cross entropy:
# Cross entropy:  0.5635996585853885
# Test cross entropy:
# Cross entropy:  0.7233207894701689
# EPOCH NUMBER:  85
# Train cross entropy:
# Cross entropy:  0.5634477284260168
# Test cross entropy:
# Cross entropy:  0.7235822115499725
# EPOCH NUMBER:  86
# Train cross entropy:
# Cross entropy:  0.5632986138008907
# Test cross entropy:
# Cross entropy:  0.7238360225903719
# EPOCH NUMBER:  87
# Train cross entropy:
# Cross entropy:  0.563152182783556
# Test cross entropy:
# Cross entropy:  0.7240823382907953
# EPOCH NUMBER:  88
# Train cross entropy:
# Cross entropy:  0.5630083107785372
# Test cross entropy:
# Cross entropy:  0.7243212784060196
# EPOCH NUMBER:  89
# Train cross entropy:
# Cross entropy:  0.5628668800932564
# Test cross entropy:
# Cross entropy:  0.7245529666651999
# EPOCH NUMBER:  90
# Train cross entropy:
# Cross entropy:  0.5627277795632861
# Test cross entropy:
# Cross entropy:  0.7247775308209048
# EPOCH NUMBER:  91
# Train cross entropy:
# Cross entropy:  0.5625909042242916
# Test cross entropy:
# Cross entropy:  0.7249951027821376
# EPOCH NUMBER:  92
# Train cross entropy:
# Cross entropy:  0.5624561550235269
# Test cross entropy:
# Cross entropy:  0.7252058187871454
# EPOCH NUMBER:  93
# Train cross entropy:
# Cross entropy:  0.562323438563319
# Test cross entropy:
# Cross entropy:  0.725409819575042
# EPOCH NUMBER:  94
# Train cross entropy:
# Cross entropy:  0.5621926668686837
# Test cross entropy:
# Cross entropy:  0.7256072505196753
# EPOCH NUMBER:  95
# Train cross entropy:
# Cross entropy:  0.5620637571711785
# Test cross entropy:
# Cross entropy:  0.725798261694692
# EPOCH NUMBER:  96
# Train cross entropy:
# Cross entropy:  0.5619366317014514
# Test cross entropy:
# Cross entropy:  0.7259830078450136
# EPOCH NUMBER:  97
# Train cross entropy:
# Cross entropy:  0.5618112174838168
# Test cross entropy:
# Cross entropy:  0.7261616482468003
# EPOCH NUMBER:  98
# Train cross entropy:
# Cross entropy:  0.5616874461276747
# Test cross entropy:
# Cross entropy:  0.7263343464450486
# EPOCH NUMBER:  99
# Train cross entropy:
# Cross entropy:  0.5615652536127042
# Test cross entropy:
# Cross entropy:  0.7265012698651445
# EPOCH NUMBER:  0
# Train cross entropy:
# Cross entropy:  1.754852114138926
# Test cross entropy:
# Cross entropy:  2.3061926325219724
# EPOCH NUMBER:  1
# Train cross entropy:
# Cross entropy:  0.9161330927871421
# Test cross entropy:
# Cross entropy:  1.1543173147879187
# EPOCH NUMBER:  2
# Train cross entropy:
# Cross entropy:  0.7064976306391945
# Test cross entropy:
# Cross entropy:  0.8273322364619263
# EPOCH NUMBER:  3
# Train cross entropy:
# Cross entropy:  0.6177630545116086
# Test cross entropy:
# Cross entropy:  0.7212979945654006
# EPOCH NUMBER:  4
# Train cross entropy:
# Cross entropy:  0.5622486154107439
# Test cross entropy:
# Cross entropy:  0.6663162081363343
# EPOCH NUMBER:  5
# Train cross entropy:
# Cross entropy:  0.5226792865743136
# Test cross entropy:
# Cross entropy:  0.6323068130755471
# EPOCH NUMBER:  6
# Train cross entropy:
# Cross entropy:  0.4922926340899485
# Test cross entropy:
# Cross entropy:  0.6086974996305848
# EPOCH NUMBER:  7
# Train cross entropy:
# Cross entropy:  0.467750117502437
# Test cross entropy:
# Cross entropy:  0.591017961205607
# EPOCH NUMBER:  8
# Train cross entropy:
# Cross entropy:  0.4472063693838219
# Test cross entropy:
# Cross entropy:  0.5770600100386082
# EPOCH NUMBER:  9
# Train cross entropy:
# Cross entropy:  0.42953081584571934
# Test cross entropy:
# Cross entropy:  0.5655552567784432
# EPOCH NUMBER:  10
# Train cross entropy:
# Cross entropy:  0.41398091189127645
# Test cross entropy:
# Cross entropy:  0.5557055005612872
# EPOCH NUMBER:  11
# Train cross entropy:
# Cross entropy:  0.4000550122915474
# Test cross entropy:
# Cross entropy:  0.5470065550446477
# EPOCH NUMBER:  12
# Train cross entropy:
# Cross entropy:  0.3874198299115061
# Test cross entropy:
# Cross entropy:  0.5391631753087363
# EPOCH NUMBER:  13
# Train cross entropy:
# Cross entropy:  0.37585650290443207
# Test cross entropy:
# Cross entropy:  0.5320173773375831
# EPOCH NUMBER:  14
# Train cross entropy:
# Cross entropy:  0.36521444268622233
# Test cross entropy:
# Cross entropy:  0.5254907567921684
# EPOCH NUMBER:  15
# Train cross entropy:
# Cross entropy:  0.3553856027931911
# Test cross entropy:
# Cross entropy:  0.5195639463373941
# EPOCH NUMBER:  16
# Train cross entropy:
# Cross entropy:  0.3462946666327295
# Test cross entropy:
# Cross entropy:  0.5142728060510348
# EPOCH NUMBER:  17
# Train cross entropy:
# Cross entropy:  0.3378822043388613
# Test cross entropy:
# Cross entropy:  0.5096497008260069
# EPOCH NUMBER:  18
# Train cross entropy:
# Cross entropy:  0.3300847260565628
# Test cross entropy:
# Cross entropy:  0.5056596449149483
# EPOCH NUMBER:  19
# Train cross entropy:
# Cross entropy:  0.32283420225465737
# Test cross entropy:
# Cross entropy:  0.5022292240626349
# EPOCH NUMBER:  20
# Train cross entropy:
# Cross entropy:  0.3160665656535171
# Test cross entropy:
# Cross entropy:  0.4992926157102431
# EPOCH NUMBER:  21
# Train cross entropy:
# Cross entropy:  0.30972565763659754
# Test cross entropy:
# Cross entropy:  0.4968018967714695
# EPOCH NUMBER:  22
# Train cross entropy:
# Cross entropy:  0.3037633321727755
# Test cross entropy:
# Cross entropy:  0.4947228093099784
# EPOCH NUMBER:  23
# Train cross entropy:
# Cross entropy:  0.29813838836923895
# Test cross entropy:
# Cross entropy:  0.49302980242837574
# EPOCH NUMBER:  24
# Train cross entropy:
# Cross entropy:  0.2928153449984333
# Test cross entropy:
# Cross entropy:  0.4917021736684645
# EPOCH NUMBER:  25
# Train cross entropy:
# Cross entropy:  0.28776327908153954
# Test cross entropy:
# Cross entropy:  0.49072096768135387
# EPOCH NUMBER:  26
# Train cross entropy:
# Cross entropy:  0.28295479052275135
# Test cross entropy:
# Cross entropy:  0.49006659716582773
# EPOCH NUMBER:  27
# Train cross entropy:
# Cross entropy:  0.27836520372418616
# Test cross entropy:
# Cross entropy:  0.4897174759476956
# EPOCH NUMBER:  28
# Train cross entropy:
# Cross entropy:  0.273972116335681
# Test cross entropy:
# Cross entropy:  0.48964981864321977
# EPOCH NUMBER:  29
# Train cross entropy:
# Cross entropy:  0.2697552860267524
# Test cross entropy:
# Cross entropy:  0.4898383545332215
# EPOCH NUMBER:  30
# Train cross entropy:
# Cross entropy:  0.26569671803911565
# Test cross entropy:
# Cross entropy:  0.49025744324160836
# EPOCH NUMBER:  31
# Train cross entropy:
# Cross entropy:  0.26178078495836193
# Test cross entropy:
# Cross entropy:  0.4908821428603887
# EPOCH NUMBER:  32
# Train cross entropy:
# Cross entropy:  0.25799427097936983
# Test cross entropy:
# Cross entropy:  0.49168902591619373
# EPOCH NUMBER:  33
# Train cross entropy:
# Cross entropy:  0.25432631573067466
# Test cross entropy:
# Cross entropy:  0.49265675486271027
# EPOCH NUMBER:  34
# Train cross entropy:
# Cross entropy:  0.25076827666089685
# Test cross entropy:
# Cross entropy:  0.4937665072102925
# EPOCH NUMBER:  35
# Train cross entropy:
# Cross entropy:  0.24731352972324527
# Test cross entropy:
# Cross entropy:  0.4950023041241017
# EPOCH NUMBER:  36
# Train cross entropy:
# Cross entropy:  0.2439572238518391
# Test cross entropy:
# Cross entropy:  0.496351229589897
# EPOCH NUMBER:  37
# Train cross entropy:
# Cross entropy:  0.24069601450811282
# Test cross entropy:
# Cross entropy:  0.49780344681814787
# EPOCH NUMBER:  38
# Train cross entropy:
# Cross entropy:  0.23752779610381428
# Test cross entropy:
# Cross entropy:  0.4993517948321634
# EPOCH NUMBER:  39
# Train cross entropy:
# Cross entropy:  0.23445140650616703
# Test cross entropy:
# Cross entropy:  0.5009906860643146
# EPOCH NUMBER:  40
# Train cross entropy:
# Cross entropy:  0.23146624346861983
# Test cross entropy:
# Cross entropy:  0.5027142884036101
# EPOCH NUMBER:  41
# Train cross entropy:
# Cross entropy:  0.22857179371979303
# Test cross entropy:
# Cross entropy:  0.5045146454627801
# EPOCH NUMBER:  42
# Train cross entropy:
# Cross entropy:  0.22576718867096573
# Test cross entropy:
# Cross entropy:  0.5063809155283456
# EPOCH NUMBER:  43
# Train cross entropy:
# Cross entropy:  0.22305093173729315
# Test cross entropy:
# Cross entropy:  0.5083003976082219
# EPOCH NUMBER:  44
# Train cross entropy:
# Cross entropy:  0.22042084672841797
# Test cross entropy:
# Cross entropy:  0.5102606521680629
# EPOCH NUMBER:  45
# Train cross entropy:
# Cross entropy:  0.21787418129036137
# Test cross entropy:
# Cross entropy:  0.5122513527574324
# EPOCH NUMBER:  46
# Train cross entropy:
# Cross entropy:  0.21540776900387462
# Test cross entropy:
# Cross entropy:  0.5142651378667086
# EPOCH NUMBER:  47
# Train cross entropy:
# Cross entropy:  0.21301818977378223
# Test cross entropy:
# Cross entropy:  0.5162975910981867
# EPOCH NUMBER:  48
# Train cross entropy:
# Cross entropy:  0.21070190812753825
# Test cross entropy:
# Cross entropy:  0.51834674609646
# EPOCH NUMBER:  49
# Train cross entropy:
# Cross entropy:  0.20845538671221533
# Test cross entropy:
# Cross entropy:  0.5204123993390779
# EPOCH NUMBER:  50
# Train cross entropy:
# Cross entropy:  0.2062751729888666
# Test cross entropy:
# Cross entropy:  0.5224954006405094
# EPOCH NUMBER:  51
# Train cross entropy:
# Cross entropy:  0.20415795648557808
# Test cross entropy:
# Cross entropy:  0.5245970500574109
# EPOCH NUMBER:  52
# Train cross entropy:
# Cross entropy:  0.2021005989807599
# Test cross entropy:
# Cross entropy:  0.5267186800246181
# EPOCH NUMBER:  53
# Train cross entropy:
# Cross entropy:  0.20010014567505097
# Test cross entropy:
# Cross entropy:  0.5288614257054818
# EPOCH NUMBER:  54
# Train cross entropy:
# Cross entropy:  0.19815382642281698
# Test cross entropy:
# Cross entropy:  0.5310261331139177
# EPOCH NUMBER:  55
# Train cross entropy:
# Cross entropy:  0.1962590525021787
# Test cross entropy:
# Cross entropy:  0.5332133479395016
# EPOCH NUMBER:  56
# Train cross entropy:
# Cross entropy:  0.19441340909361013
# Test cross entropy:
# Cross entropy:  0.5354233482236737
# EPOCH NUMBER:  57
# Train cross entropy:
# Cross entropy:  0.19261464008925083
# Test cross entropy:
# Cross entropy:  0.5376562022564345
# EPOCH NUMBER:  58
# Train cross entropy:
# Cross entropy:  0.1908606231153316
# Test cross entropy:
# Cross entropy:  0.5399118370407894
# EPOCH NUMBER:  59
# Train cross entropy:
# Cross entropy:  0.18914933885600685
# Test cross entropy:
# Cross entropy:  0.5421900982535574
# EPOCH NUMBER:  60
# Train cross entropy:
# Cross entropy:  0.18747884514643876
# Test cross entropy:
# Cross entropy:  0.5444907830730421
# EPOCH NUMBER:  61
# Train cross entropy:
# Cross entropy:  0.18584726628600998
# Test cross entropy:
# Cross entropy:  0.5468136392293131
# EPOCH NUMBER:  62
# Train cross entropy:
# Cross entropy:  0.18425280005739333
# Test cross entropy:
# Cross entropy:  0.549158340247964
# EPOCH NUMBER:  63
# Train cross entropy:
# Cross entropy:  0.18269373464404715
# Test cross entropy:
# Cross entropy:  0.5515244558366282
# EPOCH NUMBER:  64
# Train cross entropy:
# Cross entropy:  0.18116846235569195
# Test cross entropy:
# Cross entropy:  0.5539114339756774
# EPOCH NUMBER:  65
# Train cross entropy:
# Cross entropy:  0.17967547981537715
# Test cross entropy:
# Cross entropy:  0.5563186038379079
# EPOCH NUMBER:  66
# Train cross entropy:
# Cross entropy:  0.17821337261133896
# Test cross entropy:
# Cross entropy:  0.5587452024921903
# EPOCH NUMBER:  67
# Train cross entropy:
# Cross entropy:  0.17678079094691904
# Test cross entropy:
# Cross entropy:  0.5611904237637276
# EPOCH NUMBER:  68
# Train cross entropy:
# Cross entropy:  0.17537642669020825
# Test cross entropy:
# Cross entropy:  0.563653482447154
# EPOCH NUMBER:  69
# Train cross entropy:
# Cross entropy:  0.1739990002931333
# Test cross entropy:
# Cross entropy:  0.5661336817088399
# EPOCH NUMBER:  70
# Train cross entropy:
# Cross entropy:  0.1726472611512947
# Test cross entropy:
# Cross entropy:  0.5686304688937331
# EPOCH NUMBER:  71
# Train cross entropy:
# Cross entropy:  0.17132000095092736
# Test cross entropy:
# Cross entropy:  0.571143466794689
# EPOCH NUMBER:  72
# Train cross entropy:
# Cross entropy:  0.17001607815695935
# Test cross entropy:
# Cross entropy:  0.5736724722621356
# EPOCH NUMBER:  73
# Train cross entropy:
# Cross entropy:  0.1687344520250302
# Test cross entropy:
# Cross entropy:  0.5762174188239583
# EPOCH NUMBER:  74
# Train cross entropy:
# Cross entropy:  0.16747422365777567
# Test cross entropy:
# Cross entropy:  0.5787783032096927
# EPOCH NUMBER:  75
# Train cross entropy:
# Cross entropy:  0.16623467686327925
# Test cross entropy:
# Cross entropy:  0.5813550786968459
# EPOCH NUMBER:  76
# Train cross entropy:
# Cross entropy:  0.16501530285700675
# Test cross entropy:
# Cross entropy:  0.583947524345184
# EPOCH NUMBER:  77
# Train cross entropy:
# Cross entropy:  0.16381578730358795
# Test cross entropy:
# Cross entropy:  0.5865551105367302
# EPOCH NUMBER:  78
# Train cross entropy:
# Cross entropy:  0.1626359492955591
# Test cross entropy:
# Cross entropy:  0.5891768942832774
# EPOCH NUMBER:  79
# Train cross entropy:
# Cross entropy:  0.16147565203219588
# Test cross entropy:
# Cross entropy:  0.5918114828129181
# EPOCH NUMBER:  80
# Train cross entropy:
# Cross entropy:  0.16033472700735008
# Test cross entropy:
# Cross entropy:  0.5944570941096244
# EPOCH NUMBER:  81
# Train cross entropy:
# Cross entropy:  0.15921293723656782
# Test cross entropy:
# Cross entropy:  0.5971117234823113
# EPOCH NUMBER:  82
# Train cross entropy:
# Cross entropy:  0.1581099681244411
# Test cross entropy:
# Cross entropy:  0.5997734012100234
# EPOCH NUMBER:  83
# Train cross entropy:
# Cross entropy:  0.15702542270416442
# Test cross entropy:
# Cross entropy:  0.6024404884904706
# EPOCH NUMBER:  84
# Train cross entropy:
# Cross entropy:  0.155958817152965
# Test cross entropy:
# Cross entropy:  0.6051119134786543
# EPOCH NUMBER:  85
# Train cross entropy:
# Cross entropy:  0.15490958865117693
# Test cross entropy:
# Cross entropy:  0.6077872481287764
# EPOCH NUMBER:  86
# Train cross entropy:
# Cross entropy:  0.1538771217974468
# Test cross entropy:
# Cross entropy:  0.6104666039112832
# EPOCH NUMBER:  87
# Train cross entropy:
# Cross entropy:  0.15286078613643514
# Test cross entropy:
# Cross entropy:  0.6131504217829856
# EPOCH NUMBER:  88
# Train cross entropy:
# Cross entropy:  0.15185997337889612
# Test cross entropy:
# Cross entropy:  0.6158392621462695
# EPOCH NUMBER:  89
# Train cross entropy:
# Cross entropy:  0.150874127988921
# Test cross entropy:
# Cross entropy:  0.6185336569542258
# EPOCH NUMBER:  90
# Train cross entropy:
# Cross entropy:  0.14990277002584612
# Test cross entropy:
# Cross entropy:  0.6212340263080155
# EPOCH NUMBER:  91
# Train cross entropy:
# Cross entropy:  0.148945510634488
# Test cross entropy:
# Cross entropy:  0.6239406283755361
# EPOCH NUMBER:  92
# Train cross entropy:
# Cross entropy:  0.14800206008401093
# Test cross entropy:
# Cross entropy:  0.6266535079160567
# EPOCH NUMBER:  93
# Train cross entropy:
# Cross entropy:  0.1470722282256001
# Test cross entropy:
# Cross entropy:  0.6293724230002564
# EPOCH NUMBER:  94
# Train cross entropy:
# Cross entropy:  0.14615591833825173
# Test cross entropy:
# Cross entropy:  0.63209675109548
# EPOCH NUMBER:  95
# Train cross entropy:
# Cross entropy:  0.14525311625133655
# Test cross entropy:
# Cross entropy:  0.6348253972255388
# EPOCH NUMBER:  96
# Train cross entropy:
# Cross entropy:  0.14436387545066595
# Test cross entropy:
# Cross entropy:  0.6375567422614397
# EPOCH NUMBER:  97
# Train cross entropy:
# Cross entropy:  0.14348829556070591
# Test cross entropy:
# Cross entropy:  0.6402886733597127
# EPOCH NUMBER:  98
# Train cross entropy:
# Cross entropy:  0.14262648959803112
# Test cross entropy:
# Cross entropy:  0.64301872661583
# EPOCH NUMBER:  99
# Train cross entropy:
# Cross entropy:  0.14177853929353607
# Test cross entropy:
# Cross entropy:  0.6457443401196887
# EPOCH NUMBER:  0
# Train cross entropy:
# Cross entropy:  1.5749296233103975
# Test cross entropy:
# Cross entropy:  2.3213497203485405
# EPOCH NUMBER:  1
# Train cross entropy:
# Cross entropy:  0.8011903909420386
# Test cross entropy:
# Cross entropy:  0.9964278634237935
# EPOCH NUMBER:  2
# Train cross entropy:
# Cross entropy:  0.652168271117283
# Test cross entropy:
# Cross entropy:  0.7625984372753101
# EPOCH NUMBER:  3
# Train cross entropy:
# Cross entropy:  0.5831078645853057
# Test cross entropy:
# Cross entropy:  0.6832158871882361
# EPOCH NUMBER:  4
# Train cross entropy:
# Cross entropy:  0.5362963323075218
# Test cross entropy:
# Cross entropy:  0.6374622949765808
# EPOCH NUMBER:  5
# Train cross entropy:
# Cross entropy:  0.5004398548312828
# Test cross entropy:
# Cross entropy:  0.6056896899875615
# EPOCH NUMBER:  6
# Train cross entropy:
# Cross entropy:  0.47121364276802846
# Test cross entropy:
# Cross entropy:  0.5817338599106409
# EPOCH NUMBER:  7
# Train cross entropy:
# Cross entropy:  0.4463940041419269
# Test cross entropy:
# Cross entropy:  0.5627307723601889
# EPOCH NUMBER:  8
# Train cross entropy:
# Cross entropy:  0.4247116075011114
# Test cross entropy:
# Cross entropy:  0.5470342112707713
# EPOCH NUMBER:  9
# Train cross entropy:
# Cross entropy:  0.4053830785587604
# Test cross entropy:
# Cross entropy:  0.5336526442496445
# EPOCH NUMBER:  10
# Train cross entropy:
# Cross entropy:  0.38789372682635703
# Test cross entropy:
# Cross entropy:  0.5219925085667312
# EPOCH NUMBER:  11
# Train cross entropy:
# Cross entropy:  0.37189214255781616
# Test cross entropy:
# Cross entropy:  0.5116859091540694
# EPOCH NUMBER:  12
# Train cross entropy:
# Cross entropy:  0.3571315646011857
# Test cross entropy:
# Cross entropy:  0.5024866086750518
# EPOCH NUMBER:  13
# Train cross entropy:
# Cross entropy:  0.34343237365069335
# Test cross entropy:
# Cross entropy:  0.49421853309208585
# EPOCH NUMBER:  14
# Train cross entropy:
# Cross entropy:  0.3306577461203548
# Test cross entropy:
# Cross entropy:  0.4867486331030062
# EPOCH NUMBER:  15
# Train cross entropy:
# Cross entropy:  0.3186993265544537
# Test cross entropy:
# Cross entropy:  0.4799710366354205
# EPOCH NUMBER:  16
# Train cross entropy:
# Cross entropy:  0.30746949747741137
# Test cross entropy:
# Cross entropy:  0.4737994312844659
# EPOCH NUMBER:  17
# Train cross entropy:
# Cross entropy:  0.29689690037087063
# Test cross entropy:
# Cross entropy:  0.4681642678873785
# EPOCH NUMBER:  18
# Train cross entropy:
# Cross entropy:  0.286923208912782
# Test cross entropy:
# Cross entropy:  0.46301107949494213
# EPOCH NUMBER:  19
# Train cross entropy:
# Cross entropy:  0.27750038586402376
# Test cross entropy:
# Cross entropy:  0.4582977880304291
# EPOCH NUMBER:  20
# Train cross entropy:
# Cross entropy:  0.2685881787441067
# Test cross entropy:
# Cross entropy:  0.4539907035970597
# EPOCH NUMBER:  21
# Train cross entropy:
# Cross entropy:  0.2601517509261455
# Test cross entropy:
# Cross entropy:  0.45006057680254263
# EPOCH NUMBER:  22
# Train cross entropy:
# Cross entropy:  0.2521595110065251
# Test cross entropy:
# Cross entropy:  0.4464808648038377
# EPOCH NUMBER:  23
# Train cross entropy:
# Cross entropy:  0.2445814616957143
# Test cross entropy:
# Cross entropy:  0.4432290249998357
# EPOCH NUMBER:  24
# Train cross entropy:
# Cross entropy:  0.23738846706769345
# Test cross entropy:
# Cross entropy:  0.4402884284571153
# EPOCH NUMBER:  25
# Train cross entropy:
# Cross entropy:  0.23055240868037477
# Test cross entropy:
# Cross entropy:  0.43764747018498096
# EPOCH NUMBER:  26
# Train cross entropy:
# Cross entropy:  0.22404663196547694
# Test cross entropy:
# Cross entropy:  0.43529627913661956
# EPOCH NUMBER:  27
# Train cross entropy:
# Cross entropy:  0.21784618358876204
# Test cross entropy:
# Cross entropy:  0.43322413314690433
# EPOCH NUMBER:  28
# Train cross entropy:
# Cross entropy:  0.21192786295634514
# Test cross entropy:
# Cross entropy:  0.43141865862805134
# EPOCH NUMBER:  29
# Train cross entropy:
# Cross entropy:  0.20627032878437776
# Test cross entropy:
# Cross entropy:  0.42986600759167126
# EPOCH NUMBER:  30
# Train cross entropy:
# Cross entropy:  0.20085431388244396
# Test cross entropy:
# Cross entropy:  0.4285513676767531
# EPOCH NUMBER:  31
# Train cross entropy:
# Cross entropy:  0.19566278452307495
# Test cross entropy:
# Cross entropy:  0.42745957722628486
# EPOCH NUMBER:  32
# Train cross entropy:
# Cross entropy:  0.1906808973536862
# Test cross entropy:
# Cross entropy:  0.4265757108954961
# EPOCH NUMBER:  33
# Train cross entropy:
# Cross entropy:  0.1858957685317391
# Test cross entropy:
# Cross entropy:  0.42588556401693256
# EPOCH NUMBER:  34
# Train cross entropy:
# Cross entropy:  0.18129617402826148
# Test cross entropy:
# Cross entropy:  0.4253760570503725
# EPOCH NUMBER:  35
# Train cross entropy:
# Cross entropy:  0.17687226820980653
# Test cross entropy:
# Cross entropy:  0.42503560477411123
# EPOCH NUMBER:  36
# Train cross entropy:
# Cross entropy:  0.1726153213809758
# Test cross entropy:
# Cross entropy:  0.42485440041748795
# EPOCH NUMBER:  37
# Train cross entropy:
# Cross entropy:  0.16851744776258848
# Test cross entropy:
# Cross entropy:  0.4248244309160771
# EPOCH NUMBER:  38
# Train cross entropy:
# Cross entropy:  0.16457133226755696
# Test cross entropy:
# Cross entropy:  0.42493905363595436
# EPOCH NUMBER:  39
# Train cross entropy:
# Cross entropy:  0.1607700004624315
# Test cross entropy:
# Cross entropy:  0.4251922221950508
# EPOCH NUMBER:  40
# Train cross entropy:
# Cross entropy:  0.15710667448797264
# Test cross entropy:
# Cross entropy:  0.42557772398682325
# EPOCH NUMBER:  41
# Train cross entropy:
# Cross entropy:  0.15357472873303438
# Test cross entropy:
# Cross entropy:  0.42608876359595776
# EPOCH NUMBER:  42
# Train cross entropy:
# Cross entropy:  0.15016772259888242
# Test cross entropy:
# Cross entropy:  0.42671794581663697
# EPOCH NUMBER:  43
# Train cross entropy:
# Cross entropy:  0.14687946624834713
# Test cross entropy:
# Cross entropy:  0.4274574968540756
# EPOCH NUMBER:  44
# Train cross entropy:
# Cross entropy:  0.14370408070729804
# Test cross entropy:
# Cross entropy:  0.42829954285593175
# EPOCH NUMBER:  45
# Train cross entropy:
# Cross entropy:  0.14063603400226138
# Test cross entropy:
# Cross entropy:  0.4292363429775887
# EPOCH NUMBER:  46
# Train cross entropy:
# Cross entropy:  0.13767015218228995
# Test cross entropy:
# Cross entropy:  0.4302604452728479
# EPOCH NUMBER:  47
# Train cross entropy:
# Cross entropy:  0.13480161176665328
# Test cross entropy:
# Cross entropy:  0.43136477031735065
# EPOCH NUMBER:  48
# Train cross entropy:
# Cross entropy:  0.13202592119686765
# Test cross entropy:
# Cross entropy:  0.432542640181526
# EPOCH NUMBER:  49
# Train cross entropy:
# Cross entropy:  0.12933889736064552
# Test cross entropy:
# Cross entropy:  0.4337877719092223
# EPOCH NUMBER:  50
# Train cross entropy:
# Cross entropy:  0.12673664151622033
# Test cross entropy:
# Cross entropy:  0.4350942516713927
# EPOCH NUMBER:  51
# Train cross entropy:
# Cross entropy:  0.12421551771447815
# Test cross entropy:
# Cross entropy:  0.43645650101334027
# EPOCH NUMBER:  52
# Train cross entropy:
# Cross entropy:  0.12177213600722196
# Test cross entropy:
# Cross entropy:  0.43786924148204087
# EPOCH NUMBER:  53
# Train cross entropy:
# Cross entropy:  0.11940334195649135
# Test cross entropy:
# Cross entropy:  0.4393274595261295
# EPOCH NUMBER:  54
# Train cross entropy:
# Cross entropy:  0.11710621283694148
# Test cross entropy:
# Cross entropy:  0.440826371011547
# EPOCH NUMBER:  55
# Train cross entropy:
# Cross entropy:  0.11487805920938202
# Test cross entropy:
# Cross entropy:  0.442361384894974
# EPOCH NUMBER:  56
# Train cross entropy:
# Cross entropy:  0.11271642821968685
# Test cross entropy:
# Cross entropy:  0.44392806880462776
# EPOCH NUMBER:  57
# Train cross entropy:
# Cross entropy:  0.11061910244069167
# Test cross entropy:
# Cross entropy:  0.44552212451245293
# EPOCH NUMBER:  58
# Train cross entropy:
# Cross entropy:  0.10858408648961224
# Test cross entropy:
# Cross entropy:  0.44713938576999995
# EPOCH NUMBER:  59
# Train cross entropy:
# Cross entropy:  0.10660957496791941
# Test cross entropy:
# Cross entropy:  0.4487758503652234
# EPOCH NUMBER:  60
# Train cross entropy:
# Cross entropy:  0.10469390097177135
# Test cross entropy:
# Cross entropy:  0.45042774886093667
# EPOCH NUMBER:  61
# Train cross entropy:
# Cross entropy:  0.10283547311684531
# Test cross entropy:
# Cross entropy:  0.4520916357630072
# EPOCH NUMBER:  62
# Train cross entropy:
# Cross entropy:  0.10103271560154421
# Test cross entropy:
# Cross entropy:  0.45376447412216303
# EPOCH NUMBER:  63
# Train cross entropy:
# Cross entropy:  0.09928402519662023
# Test cross entropy:
# Cross entropy:  0.45544368354514725
# EPOCH NUMBER:  64
# Train cross entropy:
# Cross entropy:  0.097587751524086
# Test cross entropy:
# Cross entropy:  0.457127136920677
# EPOCH NUMBER:  65
# Train cross entropy:
# Cross entropy:  0.09594219824332847
# Test cross entropy:
# Cross entropy:  0.4588131121578748
# EPOCH NUMBER:  66
# Train cross entropy:
# Cross entropy:  0.09434563790605702
# Test cross entropy:
# Cross entropy:  0.4605002182467101
# EPOCH NUMBER:  67
# Train cross entropy:
# Cross entropy:  0.0927963329050943
# Test cross entropy:
# Cross entropy:  0.46218731564936977
# EPOCH NUMBER:  68
# Train cross entropy:
# Cross entropy:  0.0912925569192283
# Test cross entropy:
# Cross entropy:  0.46387344446811307
# EPOCH NUMBER:  69
# Train cross entropy:
# Cross entropy:  0.0898326135594788
# Test cross entropy:
# Cross entropy:  0.4655577664821567
# EPOCH NUMBER:  70
# Train cross entropy:
# Cross entropy:  0.08841485074936037
# Test cross entropy:
# Cross entropy:  0.46723952204227087
# EPOCH NUMBER:  71
# Train cross entropy:
# Cross entropy:  0.08703767060779449
# Test cross entropy:
# Cross entropy:  0.46891800010348256
# EPOCH NUMBER:  72
# Train cross entropy:
# Cross entropy:  0.08569953532499353
# Test cross entropy:
# Cross entropy:  0.4705925186128376
# EPOCH NUMBER:  73
# Train cross entropy:
# Cross entropy:  0.08439896984707895
# Test cross entropy:
# Cross entropy:  0.47226241239214367
# EPOCH NUMBER:  74
# Train cross entropy:
# Cross entropy:  0.08313456224728427
# Test cross entropy:
# Cross entropy:  0.47392702611625337
# EPOCH NUMBER:  75
# Train cross entropy:
# Cross entropy:  0.08190496258059056
# Test cross entropy:
# Cross entropy:  0.47558571066061167
# EPOCH NUMBER:  76
# Train cross entropy:
# Cross entropy:  0.08070888087931401
# Test cross entropy:
# Cross entropy:  0.47723782174228657
# EPOCH NUMBER:  77
# Train cross entropy:
# Cross entropy:  0.07954508479671167
# Test cross entropy:
# Cross entropy:  0.47888272026583256
# EPOCH NUMBER:  78
# Train cross entropy:
# Cross entropy:  0.07841239726581078
# Test cross entropy:
# Cross entropy:  0.4805197740602949
# EPOCH NUMBER:  79
# Train cross entropy:
# Cross entropy:  0.07730969442073499
# Test cross entropy:
# Cross entropy:  0.48214836077884615
# EPOCH NUMBER:  80
# Train cross entropy:
# Cross entropy:  0.0762359039315295
# Test cross entropy:
# Cross entropy:  0.4837678716910206
# EPOCH NUMBER:  81
# Train cross entropy:
# Cross entropy:  0.07519000382961516
# Test cross entropy:
# Cross entropy:  0.4853777160037383
# EPOCH NUMBER:  82
# Train cross entropy:
# Cross entropy:  0.07417102184158324
# Test cross entropy:
# Cross entropy:  0.4869773252669447
# EPOCH NUMBER:  83
# Train cross entropy:
# Cross entropy:  0.07317803518953923
# Test cross entropy:
# Cross entropy:  0.48856615740061476
# EPOCH NUMBER:  84
# Train cross entropy:
# Cross entropy:  0.0722101707397444
# Test cross entropy:
# Cross entropy:  0.49014369995137347
# EPOCH NUMBER:  85
# Train cross entropy:
# Cross entropy:  0.07126660527734585
# Test cross entropy:
# Cross entropy:  0.4917094723593748
# EPOCH NUMBER:  86
# Train cross entropy:
# Cross entropy:  0.0703465655601259
# Test cross entropy:
# Cross entropy:  0.4932630272762366
# EPOCH NUMBER:  87
# Train cross entropy:
# Cross entropy:  0.06944932769047248
# Test cross entropy:
# Cross entropy:  0.49480395127658583
# EPOCH NUMBER:  88
# Train cross entropy:
# Cross entropy:  0.0685742152985153
# Test cross entropy:
# Cross entropy:  0.49633186556475395
# EPOCH NUMBER:  89
# Train cross entropy:
# Cross entropy:  0.0677205961137674
# Test cross entropy:
# Cross entropy:  0.49784642738435436
# EPOCH NUMBER:  90
# Train cross entropy:
# Cross entropy:  0.06688787675326009
# Test cross entropy:
# Cross entropy:  0.49934733269650644
# EPOCH NUMBER:  91
# Train cross entropy:
# Cross entropy:  0.0660754959411041
# Test cross entropy:
# Cross entropy:  0.5008343202809199
# EPOCH NUMBER:  92
# Train cross entropy:
# Cross entropy:  0.06528291678810436
# Test cross entropy:
# Cross entropy:  0.5023071768322812
# EPOCH NUMBER:  93
# Train cross entropy:
# Cross entropy:  0.06450961904616603
# Test cross entropy:
# Cross entropy:  0.5037657420803717
# EPOCH NUMBER:  94
# Train cross entropy:
# Cross entropy:  0.06375509228921562
# Test cross entropy:
# Cross entropy:  0.5052099126845259
# EPOCH NUMBER:  95
# Train cross entropy:
# Cross entropy:  0.06301883074449653
# Test cross entropy:
# Cross entropy:  0.5066396437660823
# EPOCH NUMBER:  96
# Train cross entropy:
# Cross entropy:  0.06230033010777275
# Test cross entropy:
# Cross entropy:  0.5080549473948449
# EPOCH NUMBER:  97
# Train cross entropy:
# Cross entropy:  0.06159908628230313
# Test cross entropy:
# Cross entropy:  0.5094558879470885
# EPOCH NUMBER:  98
# Train cross entropy:
# Cross entropy:  0.060914595711808614
# Test cross entropy:
# Cross entropy:  0.5108425747936811
# EPOCH NUMBER:  99
# Train cross entropy:
# Cross entropy:  0.06024635687460063
# Test cross entropy:
# Cross entropy:  0.5122151531342061
# EPOCH NUMBER:  0
# Train cross entropy:
# Cross entropy:  1.4490334142599317
# Test cross entropy:
# Cross entropy:  2.328695780687265
# EPOCH NUMBER:  1
# Train cross entropy:
# Cross entropy:  0.7478458573763115
# Test cross entropy:
# Cross entropy:  0.903906817549299
# EPOCH NUMBER:  2
# Train cross entropy:
# Cross entropy:  0.6353398603350768
# Test cross entropy:
# Cross entropy:  0.7338330400574317
# EPOCH NUMBER:  3
# Train cross entropy:
# Cross entropy:  0.5795515998740737
# Test cross entropy:
# Cross entropy:  0.6707181239520237
# EPOCH NUMBER:  4
# Train cross entropy:
# Cross entropy:  0.5412775208491422
# Test cross entropy:
# Cross entropy:  0.6336045677812012
# EPOCH NUMBER:  5
# Train cross entropy:
# Cross entropy:  0.5113997149108891
# Test cross entropy:
# Cross entropy:  0.607333555290564
# EPOCH NUMBER:  6
# Train cross entropy:
# Cross entropy:  0.486246467994242
# Test cross entropy:
# Cross entropy:  0.5865970258585753
# EPOCH NUMBER:  7
# Train cross entropy:
# Cross entropy:  0.4640407023288231
# Test cross entropy:
# Cross entropy:  0.5690426063397032
# EPOCH NUMBER:  8
# Train cross entropy:
# Cross entropy:  0.44382337214825934
# Test cross entropy:
# Cross entropy:  0.5534928279540124
# EPOCH NUMBER:  9
# Train cross entropy:
# Cross entropy:  0.4250412362151457
# Test cross entropy:
# Cross entropy:  0.5393193941400242
# EPOCH NUMBER:  10
# Train cross entropy:
# Cross entropy:  0.40736970815971757
# Test cross entropy:
# Cross entropy:  0.5261777312276906
# EPOCH NUMBER:  11
# Train cross entropy:
# Cross entropy:  0.39062400218231574
# Test cross entropy:
# Cross entropy:  0.5138784049597008
# EPOCH NUMBER:  12
# Train cross entropy:
# Cross entropy:  0.3747048856048825
# Test cross entropy:
# Cross entropy:  0.5023182769614976
# EPOCH NUMBER:  13
# Train cross entropy:
# Cross entropy:  0.3595604065556395
# Test cross entropy:
# Cross entropy:  0.49143994057949353
# EPOCH NUMBER:  14
# Train cross entropy:
# Cross entropy:  0.34515947669686464
# Test cross entropy:
# Cross entropy:  0.4812064186854305
# EPOCH NUMBER:  15
# Train cross entropy:
# Cross entropy:  0.33147634463732034
# Test cross entropy:
# Cross entropy:  0.47158679835333883
# EPOCH NUMBER:  16
# Train cross entropy:
# Cross entropy:  0.3184840563399333
# Test cross entropy:
# Cross entropy:  0.4625504739240074
# EPOCH NUMBER:  17
# Train cross entropy:
# Cross entropy:  0.3061538120680407
# Test cross entropy:
# Cross entropy:  0.45406708581555766
# EPOCH NUMBER:  18
# Train cross entropy:
# Cross entropy:  0.29445670345779423
# Test cross entropy:
# Cross entropy:  0.4461088523439263
# EPOCH NUMBER:  19
# Train cross entropy:
# Cross entropy:  0.2833651255141071
# Test cross entropy:
# Cross entropy:  0.43865265880839516
# EPOCH NUMBER:  20
# Train cross entropy:
# Cross entropy:  0.27285283182608455
# Test cross entropy:
# Cross entropy:  0.43168070636221867
# EPOCH NUMBER:  21
# Train cross entropy:
# Cross entropy:  0.26289400422303505
# Test cross entropy:
# Cross entropy:  0.42517970605216315
# EPOCH NUMBER:  22
# Train cross entropy:
# Cross entropy:  0.2534621566233403
# Test cross entropy:
# Cross entropy:  0.4191390530491564
# EPOCH NUMBER:  23
# Train cross entropy:
# Cross entropy:  0.24452944724501322
# Test cross entropy:
# Cross entropy:  0.4135485752338372
# EPOCH NUMBER:  24
# Train cross entropy:
# Cross entropy:  0.23606663767123542
# Test cross entropy:
# Cross entropy:  0.40839659960628577
# EPOCH NUMBER:  25
# Train cross entropy:
# Cross entropy:  0.22804367149967958
# Test cross entropy:
# Cross entropy:  0.4036689328580624
# EPOCH NUMBER:  26
# Train cross entropy:
# Cross entropy:  0.22043058255777517
# Test cross entropy:
# Cross entropy:  0.3993487958920453
# EPOCH NUMBER:  27
# Train cross entropy:
# Cross entropy:  0.21319837646248302
# Test cross entropy:
# Cross entropy:  0.39541726969014196
# EPOCH NUMBER:  28
# Train cross entropy:
# Cross entropy:  0.20631970421933973
# Test cross entropy:
# Cross entropy:  0.39185382084696496
# EPOCH NUMBER:  29
# Train cross entropy:
# Cross entropy:  0.1997693069537559
# Test cross entropy:
# Cross entropy:  0.388636774483642
# EPOCH NUMBER:  30
# Train cross entropy:
# Cross entropy:  0.1935242494818499
# Test cross entropy:
# Cross entropy:  0.38574379638004164
# EPOCH NUMBER:  31
# Train cross entropy:
# Cross entropy:  0.18756395737806925
# Test cross entropy:
# Cross entropy:  0.3831524294059969
# EPOCH NUMBER:  32
# Train cross entropy:
# Cross entropy:  0.181870080803868
# Test cross entropy:
# Cross entropy:  0.3808406351883176
# EPOCH NUMBER:  33
# Train cross entropy:
# Cross entropy:  0.17642622853637233
# Test cross entropy:
# Cross entropy:  0.3787872521565381
# EPOCH NUMBER:  34
# Train cross entropy:
# Cross entropy:  0.17121763662659303
# Test cross entropy:
# Cross entropy:  0.37697231116164387
# EPOCH NUMBER:  35
# Train cross entropy:
# Cross entropy:  0.16623084420523235
# Test cross entropy:
# Cross entropy:  0.37537720116028334
# EPOCH NUMBER:  36
# Train cross entropy:
# Cross entropy:  0.16145343364788106
# Test cross entropy:
# Cross entropy:  0.3739847124525653
# EPOCH NUMBER:  37
# Train cross entropy:
# Cross entropy:  0.15687385866226597
# Test cross entropy:
# Cross entropy:  0.37277899587936075
# EPOCH NUMBER:  38
# Train cross entropy:
# Cross entropy:  0.15248135062356227
# Test cross entropy:
# Cross entropy:  0.37174547169829064
# EPOCH NUMBER:  39
# Train cross entropy:
# Cross entropy:  0.14826587610147413
# Test cross entropy:
# Cross entropy:  0.37087071258808485
# EPOCH NUMBER:  40
# Train cross entropy:
# Cross entropy:  0.144218118038124
# Test cross entropy:
# Cross entropy:  0.3701423184603768
# EPOCH NUMBER:  41
# Train cross entropy:
# Cross entropy:  0.14032946116089687
# Test cross entropy:
# Cross entropy:  0.36954879795155066
# EPOCH NUMBER:  42
# Train cross entropy:
# Cross entropy:  0.13659197117918123
# Test cross entropy:
# Cross entropy:  0.3690794705035576
# EPOCH NUMBER:  43
# Train cross entropy:
# Cross entropy:  0.13299836372155316
# Test cross entropy:
# Cross entropy:  0.36872440140675394
# EPOCH NUMBER:  44
# Train cross entropy:
# Cross entropy:  0.12954196251578065
# Test cross entropy:
# Cross entropy:  0.36847437837523567
# EPOCH NUMBER:  45
# Train cross entropy:
# Cross entropy:  0.12621664777264333
# Test cross entropy:
# Cross entropy:  0.36832093039085917
# EPOCH NUMBER:  46
# Train cross entropy:
# Cross entropy:  0.12301679606394714
# Test cross entropy:
# Cross entropy:  0.3682563767173756
# EPOCH NUMBER:  47
# Train cross entropy:
# Cross entropy:  0.11993721324723586
# Test cross entropy:
# Cross entropy:  0.36827387931566263
# EPOCH NUMBER:  48
# Train cross entropy:
# Cross entropy:  0.1169730631335632
# Test cross entropy:
# Cross entropy:  0.3683674643057542
# EPOCH NUMBER:  49
# Train cross entropy:
# Cross entropy:  0.1141197966702841
# Test cross entropy:
# Cross entropy:  0.36853198688327016
# EPOCH NUMBER:  50
# Train cross entropy:
# Cross entropy:  0.11137308807827129
# Test cross entropy:
# Cross entropy:  0.36876303828785395
# EPOCH NUMBER:  51
# Train cross entropy:
# Cross entropy:  0.10872878393072706
# Test cross entropy:
# Cross entropy:  0.369056818359589
# EPOCH NUMBER:  52
# Train cross entropy:
# Cross entropy:  0.10618286838338313
# Test cross entropy:
# Cross entropy:  0.3694100061410994
# EPOCH NUMBER:  53
# Train cross entropy:
# Cross entropy:  0.10373144433536098
# Test cross entropy:
# Cross entropy:  0.3698196507899794
# EPOCH NUMBER:  54
# Train cross entropy:
# Cross entropy:  0.101370727978321
# Test cross entropy:
# Cross entropy:  0.37028308748663186
# EPOCH NUMBER:  55
# Train cross entropy:
# Cross entropy:  0.09909705323594245
# Test cross entropy:
# Cross entropy:  0.37079787134047204
# EPOCH NUMBER:  56
# Train cross entropy:
# Cross entropy:  0.0969068822179923
# Test cross entropy:
# Cross entropy:  0.37136172060581296
# EPOCH NUMBER:  57
# Train cross entropy:
# Cross entropy:  0.09479681757299557
# Test cross entropy:
# Cross entropy:  0.3719724647174396
# EPOCH NUMBER:  58
# Train cross entropy:
# Cross entropy:  0.09276361283546782
# Test cross entropy:
# Cross entropy:  0.37262799725690676
# EPOCH NUMBER:  59
# Train cross entropy:
# Cross entropy:  0.09080417790838759
# Test cross entropy:
# Cross entropy:  0.37332623632946654
# EPOCH NUMBER:  60
# Train cross entropy:
# Cross entropy:  0.0889155785335378
# Test cross entropy:
# Cross entropy:  0.37406509505184815
# EPOCH NUMBER:  61
# Train cross entropy:
# Cross entropy:  0.08709503037146943
# Test cross entropy:
# Cross entropy:  0.37484246388373604
# EPOCH NUMBER:  62
# Train cross entropy:
# Cross entropy:  0.08533988954469525
# Test cross entropy:
# Cross entropy:  0.37565620506022074
# EPOCH NUMBER:  63
# Train cross entropy:
# Cross entropy:  0.08364764190186401
# Test cross entropy:
# Cross entropy:  0.3765041577357517
# EPOCH NUMBER:  64
# Train cross entropy:
# Cross entropy:  0.0820158928708101
# Test cross entropy:
# Cross entropy:  0.377384150955668
# EPOCH NUMBER:  65
# ...
# Cross entropy:  0.39192983231007567
# EPOCH NUMBER:  79
# Train cross entropy:
# Cross entropy:  0.06344895851676899
# Test cross entropy:
# Cross entropy:  0.3930549858538017
# EPOCH NUMBER:  80
# Train cross entropy:
# Cross entropy:  0.06252798303647607
# Test cross entropy:
# Cross entropy:  0.3941835024774431
# EPOCH NUMBER:  81
# Train cross entropy:
# Cross entropy:  0.061638096354162335
# Test cross entropy:
# Cross entropy:  0.395314293724478
# EPOCH NUMBER:  82
# Train cross entropy:
# Cross entropy:  0.06077798389777606
# Test cross entropy:
# Cross entropy:  0.39644639018435857
# EPOCH NUMBER:  83
# Train cross entropy:
# Cross entropy:  0.05994638081620281
# Test cross entropy:
# Cross entropy:  0.3975789338231733
# EPOCH NUMBER:  84
# Train cross entropy:
# Cross entropy:  0.059142073289302176
# Test cross entropy:
# Cross entropy:  0.39871116787292515
# EPOCH NUMBER:  85
# Train cross entropy:
# Cross entropy:  0.05836389908010128
# Test cross entropy:
# Cross entropy:  0.399842425580625
# EPOCH NUMBER:  86
# Train cross entropy:
# Cross entropy:  0.05761074741325783
# Test cross entropy:
# Cross entropy:  0.4009721188462059
# EPOCH NUMBER:  87
# Train cross entropy:
# Cross entropy:  0.05688155829070297
# Test cross entropy:
# Cross entropy:  0.4020997274531257
# EPOCH NUMBER:  88
# Train cross entropy:
# Cross entropy:  0.05617532136114172
# Test cross entropy:
# Cross entropy:  0.4032247893012969
# EPOCH NUMBER:  89
# Train cross entropy:
# Cross entropy:  0.05549107445289667
# Test cross entropy:
# Cross entropy:  0.4043468918268369
# EPOCH NUMBER:  90
# Train cross entropy:
# Cross entropy:  0.054827901865564944
# Test cross entropy:
# Cross entropy:  0.4054656646421487
# EPOCH NUMBER:  91
# Train cross entropy:
# Cross entropy:  0.05418493249941597
# Test cross entropy:
# Cross entropy:  0.4065807733402471
# EPOCH NUMBER:  92
# Train cross entropy:
# Cross entropy:  0.05356133788516792
# Test cross entropy:
# Cross entropy:  0.40769191436092594
# EPOCH NUMBER:  93
# Train cross entropy:
# Cross entropy:  0.05295633016235181
# Test cross entropy:
# Cross entropy:  0.4087988107967536
# EPOCH NUMBER:  94
# Train cross entropy:
# Cross entropy:  0.05236916004266822
# Test cross entropy:
# Cross entropy:  0.40990120901196747
# EPOCH NUMBER:  95
# Train cross entropy:
# Cross entropy:  0.05179911478571552
# Test cross entropy:
# Cross entropy:  0.4109988759499619
# EPOCH NUMBER:  96
# Train cross entropy:
# Cross entropy:  0.05124551620799365
# Test cross entropy:
# Cross entropy:  0.4120915970115126
# EPOCH NUMBER:  97
# Train cross entropy:
# Cross entropy:  0.050707718741687474
# Test cross entropy:
# Cross entropy:  0.4131791743948
# EPOCH NUMBER:  98
# Train cross entropy:
# Cross entropy:  0.05018510755683041
# Test cross entropy:
# Cross entropy:  0.41426142579918357
# EPOCH NUMBER:  99
# Train cross entropy:
# Cross entropy:  0.04967709675845671
# Test cross entropy:
# Cross entropy:  0.41533818340727424
# EPOCH NUMBER:  0
# Train cross entropy:
# Cross entropy:  1.3208503496896666
# Test cross entropy:
# Cross entropy:  2.3181644131088692
# EPOCH NUMBER:  1
# Train cross entropy:
# Cross entropy:  0.7147156792624861
# Test cross entropy:
# Cross entropy:  0.8571651494702492
# EPOCH NUMBER:  2
# Train cross entropy:
# Cross entropy:  0.621894408089813
# Test cross entropy:
# Cross entropy:  0.7234802517128045
# EPOCH NUMBER:  3
# Train cross entropy:
# Cross entropy:  0.5739677121203284
# Test cross entropy:
# Cross entropy:  0.6700226033889384
# EPOCH NUMBER:  4
# Train cross entropy:
# Cross entropy:  0.5412448117074857
# Test cross entropy:
# Cross entropy:  0.6394297054978257
# EPOCH NUMBER:  5
# Train cross entropy:
# Cross entropy:  0.5158659635801336
# Test cross entropy:
# Cross entropy:  0.618700194262422
# EPOCH NUMBER:  6
# Train cross entropy:
# Cross entropy:  0.4945575531380444
# Test cross entropy:
# Cross entropy:  0.6028215832180046
# EPOCH NUMBER:  7
# Train cross entropy:
# Cross entropy:  0.475681300212154
# Test cross entropy:
# Cross entropy:  0.5894470837020653
# EPOCH NUMBER:  8
# Train cross entropy:
# Cross entropy:  0.45834255896021253
# Test cross entropy:
# Cross entropy:  0.5774061451063387
# EPOCH NUMBER:  9
# Train cross entropy:
# Cross entropy:  0.4420329846936526
# Test cross entropy:
# Cross entropy:  0.5661078398667073
# EPOCH NUMBER:  10
# Train cross entropy:
# Cross entropy:  0.426458619049266
# Test cross entropy:
# Cross entropy:  0.5552488091371154
# EPOCH NUMBER:  11
# Train cross entropy:
# Cross entropy:  0.4114498438930394
# Test cross entropy:
# Cross entropy:  0.5446706468186672
# EPOCH NUMBER:  12
# Train cross entropy:
# Cross entropy:  0.3969110478658505
# Test cross entropy:
# Cross entropy:  0.5342954060469866
# EPOCH NUMBER:  13
# Train cross entropy:
# Cross entropy:  0.3827914319238033
# Test cross entropy:
# Cross entropy:  0.5240955109414064
# EPOCH NUMBER:  14
# Train cross entropy:
# Cross entropy:  0.3690684984717505
# Test cross entropy:
# Cross entropy:  0.5140760932656437
# EPOCH NUMBER:  15
# Train cross entropy:
# Cross entropy:  0.3557387694722787
# Test cross entropy:
# Cross entropy:  0.5042626887441549
# EPOCH NUMBER:  16
# Train cross entropy:
# Cross entropy:  0.3428117238440806
# Test cross entropy:
# Cross entropy:  0.49469257740529554
# EPOCH NUMBER:  17
# Train cross entropy:
# Cross entropy:  0.33030460977164283
# Test cross entropy:
# Cross entropy:  0.48540871495987165
# EPOCH NUMBER:  18
# Train cross entropy:
# Cross entropy:  0.3182373780260538
# Test cross entropy:
# Cross entropy:  0.4764552210052116
# EPOCH NUMBER:  19
# Train cross entropy:
# Cross entropy:  0.30662807769698996
# Test cross entropy:
# Cross entropy:  0.4678737351282242
# EPOCH NUMBER:  20
# Train cross entropy:
# Cross entropy:  0.29548946475810384
# Test cross entropy:
# Cross entropy:  0.4597005143603255
# EPOCH NUMBER:  21
# Train cross entropy:
# Cross entropy:  0.2848273022222655
# Test cross entropy:
# Cross entropy:  0.45196462476489924
# EPOCH NUMBER:  22
# Train cross entropy:
# Cross entropy:  0.2746402153163393
# Test cross entropy:
# Cross entropy:  0.4446874825902641
# EPOCH NUMBER:  23
# Train cross entropy:
# Cross entropy:  0.2649205339986353
# Test cross entropy:
# Cross entropy:  0.43788334855118893
# EPOCH NUMBER:  24
# Train cross entropy:
# Cross entropy:  0.2556555318775165
# Test cross entropy:
# Cross entropy:  0.43155997336204405
# EPOCH NUMBER:  25
# Train cross entropy:
# Cross entropy:  0.24682866944737009
# Test cross entropy:
# Cross entropy:  0.4257189065114935
# EPOCH NUMBER:  26
# Train cross entropy:
# Cross entropy:  0.23842065629672515
# Test cross entropy:
# Cross entropy:  0.42035558369434667
# EPOCH NUMBER:  27
# Train cross entropy:
# Cross entropy:  0.2304103088299126
# Test cross entropy:
# Cross entropy:  0.41545958481554723
# EPOCH NUMBER:  28
# Train cross entropy:
# Cross entropy:  0.2227752890811408
# Test cross entropy:
# Cross entropy:  0.4110152914218677
# EPOCH NUMBER:  29
# Train cross entropy:
# Cross entropy:  0.21549282676919185
# Test cross entropy:
# Cross entropy:  0.4070028805417614
# EPOCH NUMBER:  30
# Train cross entropy:
# Cross entropy:  0.20854044205519362
# Test cross entropy:
# Cross entropy:  0.40339946035995705
# EPOCH NUMBER:  31
# Train cross entropy:
# Cross entropy:  0.20189658595235602
# Test cross entropy:
# Cross entropy:  0.40018020010457217
# EPOCH NUMBER:  32
# Train cross entropy:
# Cross entropy:  0.19554110108728714
# Test cross entropy:
# Cross entropy:  0.3973193816710939
# EPOCH NUMBER:  33
# Train cross entropy:
# Cross entropy:  0.18945547132104246
# Test cross entropy:
# Cross entropy:  0.39479132141388
# EPOCH NUMBER:  34
# Train cross entropy:
# Cross entropy:  0.1836228972871434
# Test cross entropy:
# Cross entropy:  0.39257111393766797
# EPOCH NUMBER:  35
# Train cross entropy:
# Cross entropy:  0.1780282644872148
# Test cross entropy:
# Cross entropy:  0.3906351741376541
# EPOCH NUMBER:  36
# Train cross entropy:
# Cross entropy:  0.1726580644195512
# Test cross entropy:
# Cross entropy:  0.3889615879362057
# EPOCH NUMBER:  37
# Train cross entropy:
# Cross entropy:  0.1675003024278799
# Test cross entropy:
# Cross entropy:  0.3875303016771749
# EPOCH NUMBER:  38
# Train cross entropy:
# Cross entropy:  0.1625443960384135
# Test cross entropy:
# Cross entropy:  0.3863231756874055
# EPOCH NUMBER:  39
# Train cross entropy:
# Cross entropy:  0.1577810493795226
# Test cross entropy:
# Cross entropy:  0.38532390699626107
# EPOCH NUMBER:  40
# Train cross entropy:
# Cross entropy:  0.15320208731784757
# Test cross entropy:
# Cross entropy:  0.3845178069767891
# EPOCH NUMBER:  41
# Train cross entropy:
# Cross entropy:  0.14880024355639893
# Test cross entropy:
# Cross entropy:  0.3838914209256029
# EPOCH NUMBER:  42
# Train cross entropy:
# Cross entropy:  0.14456891639714498
# Test cross entropy:
# Cross entropy:  0.3834320146172604
# EPOCH NUMBER:  43
# Train cross entropy:
# Cross entropy:  0.14050192903202213
# Test cross entropy:
# Cross entropy:  0.3831270272002595
# EPOCH NUMBER:  44
# Train cross entropy:
# Cross entropy:  0.13659334340581744
# Test cross entropy:
# Cross entropy:  0.3829636570189949
# EPOCH NUMBER:  45
# Train cross entropy:
# Cross entropy:  0.13283736094829685
# Test cross entropy:
# Cross entropy:  0.38292872919676335
# EPOCH NUMBER:  46
# Train cross entropy:
# Cross entropy:  0.12922830522928005
# Test cross entropy:
# Cross entropy:  0.3830088657910941
# EPOCH NUMBER:  47
# Train cross entropy:
# Cross entropy:  0.12576065095522568
# Test cross entropy:
# Cross entropy:  0.3831908355153938
# EPOCH NUMBER:  48
# Train cross entropy:
# Cross entropy:  0.12242906134596453
# Test cross entropy:
# Cross entropy:  0.38346192045368316
# EPOCH NUMBER:  49
# Train cross entropy:
# Cross entropy:  0.11922841283193586
# Test cross entropy:
# Cross entropy:  0.3838102047925247
# EPOCH NUMBER:  50
# Train cross entropy:
# Cross entropy:  0.1161538028773416
# Test cross entropy:
# Cross entropy:  0.3842247746021958
# EPOCH NUMBER:  51
# Train cross entropy:
# Cross entropy:  0.11320054509377096
# Test cross entropy:
# Cross entropy:  0.3846958552461064
# EPOCH NUMBER:  52
# Train cross entropy:
# Cross entropy:  0.11036415740257219
# Test cross entropy:
# Cross entropy:  0.3852149077147875
# EPOCH NUMBER:  53
# Train cross entropy:
# Cross entropy:  0.10764034752808414
# Test cross entropy:
# Cross entropy:  0.385774686095827
# EPOCH NUMBER:  54
# Train cross entropy:
# Cross entropy:  0.10502499782826691
# Test cross entropy:
# Cross entropy:  0.3863692452266588
# EPOCH NUMBER:  55
# Train cross entropy:
# Cross entropy:  0.10251414933132111
# Test cross entropy:
# Cross entropy:  0.386993885826376
# EPOCH NUMBER:  56
# Train cross entropy:
# Cross entropy:  0.10010398304436642
# Test cross entropy:
# Cross entropy:  0.3876450321467903
# EPOCH NUMBER:  57
# Train cross entropy:
# Cross entropy:  0.09779079551020275
# Test cross entropy:
# Cross entropy:  0.388320050227059
# EPOCH NUMBER:  58
# Train cross entropy:
# Cross entropy:  0.09557096655659635
# Test cross entropy:
# Cross entropy:  0.38901702827220586
# EPOCH NUMBER:  59
# Train cross entropy:
# Cross entropy:  0.09344092153445095
# Test cross entropy:
# Cross entropy:  0.3897345495340127
# EPOCH NUMBER:  60
# Train cross entropy:
# Cross entropy:  0.09139709662675807
# Test cross entropy:
# Cross entropy:  0.39047148871271325
# EPOCH NUMBER:  61
# Train cross entropy:
# Cross entropy:  0.0894359190488635
# Test cross entropy:
# Cross entropy:  0.3912268546213267
# EPOCH NUMBER:  62
# Train cross entropy:
# Cross entropy:  0.08755381001064913
# Test cross entropy:
# Cross entropy:  0.3919996876929719
# EPOCH NUMBER:  63
# Train cross entropy:
# Cross entropy:  0.08574720908929484
# Test cross entropy:
# Cross entropy:  0.39278900666655353
# EPOCH NUMBER:  64
# Train cross entropy:
# Cross entropy:  0.08401261077429263
# Test cross entropy:
# Cross entropy:  0.39359378996622996
# EPOCH NUMBER:  65
# Train cross entropy:
# Cross entropy:  0.0823466020332418
# Test cross entropy:
# Cross entropy:  0.394412975824799
# EPOCH NUMBER:  66
# Train cross entropy:
# Cross entropy:  0.08074589301916792
# Test cross entropy:
# Cross entropy:  0.39524546896619356
# EPOCH NUMBER:  67
# Train cross entropy:
# Cross entropy:  0.0792073378353932
# Test cross entropy:
# Cross entropy:  0.3960901469970792
# EPOCH NUMBER:  68
# Train cross entropy:
# Cross entropy:  0.07772794582797603
# Test cross entropy:
# Cross entropy:  0.3969458640015129
# EPOCH NUMBER:  69
# Train cross entropy:
# Cross entropy:  0.07630488549675468
# Test cross entropy:
# Cross entropy:  0.39781145144444485
# EPOCH NUMBER:  70
# Train cross entropy:
# Cross entropy:  0.07493548333785657
# Test cross entropy:
# Cross entropy:  0.39868571772677724
# EPOCH NUMBER:  71
# Train cross entropy:
# Cross entropy:  0.07361721949102638
# Test cross entropy:
# Cross entropy:  0.39956744818409257
# EPOCH NUMBER:  72
# Train cross entropy:
# Cross entropy:  0.07234772146111629
# Test cross entropy:
# Cross entropy:  0.4004554073791344
# EPOCH NUMBER:  73
# Train cross entropy:
# Cross entropy:  0.07112475664860032
# Test cross entropy:
# Cross entropy:  0.40134834536089875
# EPOCH NUMBER:  74
# Train cross entropy:
# Cross entropy:  0.06994622403840221
# Test cross entropy:
# Cross entropy:  0.40224500916204375
# EPOCH NUMBER:  75
# Train cross entropy:
# Cross entropy:  0.06881014517584601
# Test cross entropy:
# Cross entropy:  0.4031441601544104
# EPOCH NUMBER:  76
# Train cross entropy:
# Cross entropy:  0.06771465449888364
# Test cross entropy:
# Cross entropy:  0.4040445969928504
# EPOCH NUMBER:  77
# Train cross entropy:
# Cross entropy:  0.06665798917660556
# Test cross entropy:
# Cross entropy:  0.40494518284849057
# EPOCH NUMBER:  78
# Train cross entropy:
# Cross entropy:  0.06563847877666784
# Test cross entropy:
# Cross entropy:  0.40584487465255153
# EPOCH NUMBER:  79
# Train cross entropy:
# Cross entropy:  0.06465453526674853
# Test cross entropy:
# Cross entropy:  0.4067427513779784
# EPOCH NUMBER:  80
# Train cross entropy:
# Cross entropy:  0.06370464395244685
# Test cross entropy:
# Cross entropy:  0.40763803818230165
# EPOCH NUMBER:  81
# Train cross entropy:
# Cross entropy:  0.06278735589958054
# Test cross entropy:
# Cross entropy:  0.40853012360636076
# EPOCH NUMBER:  82
# Train cross entropy:
# Cross entropy:  0.061901282181074734
# Test cross entropy:
# Cross entropy:  0.40941856789558584
# EPOCH NUMBER:  83
# Train cross entropy:
# Cross entropy:  0.061045089993620676
# Test cross entropy:
# Cross entropy:  0.4103031016807461
# EPOCH NUMBER:  84
# Train cross entropy:
# Cross entropy:  0.06021750040466268
# Test cross entropy:
# Cross entropy:  0.4111836154703606
# EPOCH NUMBER:  85
# Train cross entropy:
# Cross entropy:  0.05941728729625809
# Test cross entropy:
# Cross entropy:  0.41206014144189557
# EPOCH NUMBER:  86
# Train cross entropy:
# Cross entropy:  0.058643277001475466
# Test cross entropy:
# Cross entropy:  0.41293282972027245
# EPOCH NUMBER:  87
# Train cross entropy:
# Cross entropy:  0.057894348166729226
# Test cross entropy:
# Cross entropy:  0.41380192163254376
# EPOCH NUMBER:  88
# Train cross entropy:
# Cross entropy:  0.05716943147911654
# Test cross entropy:
# Cross entropy:  0.4146677223413254
# EPOCH NUMBER:  89
# Train cross entropy:
# Cross entropy:  0.05646750902764593
# Test cross entropy:
# Cross entropy:  0.41553057486921857
# EPOCH NUMBER:  90
# Train cross entropy:
# Cross entropy:  0.05578761318866019
# Test cross entropy:
# Cross entropy:  0.4163908369567545
# EPOCH NUMBER:  91
# Train cross entropy:
# Cross entropy:  0.05512882502148862
# Test cross entropy:
# Cross entropy:  0.41724886158075025
# EPOCH NUMBER:  92
# Train cross entropy:
# Cross entropy:  0.05449027222598662
# Test cross entropy:
# Cross entropy:  0.4181049814088295
# EPOCH NUMBER:  93
# Train cross entropy:
# Cross entropy:  0.05387112675260599
# Test cross entropy:
# Cross entropy:  0.4189594970482013
# EPOCH NUMBER:  94
# Train cross entropy:
# Cross entropy:  0.053270602174635306
# Test cross entropy:
# Cross entropy:  0.4198126686870707
# EPOCH NUMBER:  95
# Train cross entropy:
# Cross entropy:  0.05268795093769678
# Test cross entropy:
# Cross entropy:  0.420664710613789
# EPOCH NUMBER:  96
# Train cross entropy:
# Cross entropy:  0.05212246159805827
# Test cross entropy:
# Cross entropy:  0.42151578809807816
# EPOCH NUMBER:  97
# Train cross entropy:
# Cross entropy:  0.051573456151242494
# Test cross entropy:
# Cross entropy:  0.422366016187268
# EPOCH NUMBER:  98
# Train cross entropy:
# Cross entropy:  0.05104028753681717
# Test cross entropy:
# Cross entropy:  0.4232154600666885
# EPOCH NUMBER:  99
# Train cross entropy:
# Cross entropy:  0.05052233738480546
# Test cross entropy:
# Cross entropy:  0.424064136723929

# %%
tmp_test = []
tmp_train = []
for value in final_values_test:
  tmp_test.append(value[99])

for value in final_values_train:
  tmp_train.append(value[99])

epochs = [i for i in range(1, 6)]
plt.title('Varying number of hidden units')
plt.xlabel("Hidden units")
plt.ylabel("cross-entropy")
plt.plot(epochs, tmp_test, color='green', label='Test cross-entropy')
plt.plot(epochs, tmp_train, color='red', label='Training cross-entropy')
plt.legend()
plt.show()
